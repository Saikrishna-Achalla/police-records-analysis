# %% [markdown]
# My attempt to scrape NextRequest data using the `selenium` library:

# %%
# !pip install selenium

from joblib import Parallel, delayed
from selenium import webdriver
from selenium.webdriver.common.desired_capabilities import DesiredCapabilities
from selenium.webdriver.firefox.options import Options
from selenium.common.exceptions import NoSuchElementException

import sys
from tqdm import tqdm
from time import sleep

import pandas as pd
import numpy as np
import re

# Options for the driver
options = Options()
options.headless = True
# Out:
# Requirement already satisfied: selenium in /Users/stevenyuan/opt/anaconda3/lib/python3.8/site-packages (3.141.0)
# Requirement already satisfied: urllib3 in /Users/stevenyuan/opt/anaconda3/lib/python3.8/site-packages (from selenium) (1.26.4)

# %% [markdown]
# ### TO-DO
# - Generate full dataset from San Diego NextRequest database
# - Figure out if [Selenium Grid](https://www.selenium.dev/documentation/grid/) can potentially improve the performance of the scraper
# - Run on Google Colab?

# %%
. # Keep this cell to prevent the rest of the notebook from automatically running
# Out:
#   File "<ipython-input-46-b2026be2226a>", line 1
#     . # Keep this cell to prevent the rest of the notebook from automatically running
#     ^
# SyntaxError: invalid syntax

# %%
# Options for scraping
earliest_year = 16 # Earliest year to search requests for
latest_year = 21 # Latest year to search request for
id_start = 1 # ID value to start from
id_range = 9999 # Number of IDs to try for each year
cooldown = 1 # Amount of time, in seconds, to wait between website accesses

# List of all request IDs
request_ids = [str(year) + '-' + str(num) for num in range(id_start, id_range + id_start) 
                                       for year in range(earliest_year, latest_year + 1)]

# URLs to extract data from
urls = ['https://sandiego.nextrequest.com/requests/', 'https://oaklandca.nextrequest.com/requests/']

# %%
# Non-parallelized script
driver = webdriver.Firefox(options=options) # Headless (non-visible) WebDriver

sd_requests = [] # List of dictionaries containing information on each request
i = 0 # Index for URLs - may be useful later for scraping multiple sites

for year in range(earliest_year, latest_year + 1):
    for num in tqdm(range(id_start, id_range + id_start)):
        request_id = str(year) + '-' + str(num) # NextRequest request IDs are a two-digit year and a number, with a dash in between
        url = urls[i] + request_id
        driver.get(url) # Attempt to access the record
        
        # print(driver.title) # For testing purposes
        
        # If the record does not exist, then move on to the next ID
        if (request_id not in driver.title):
            sleep(cooldown)
            continue
            
        status, desc, date, depts, docs, poc, events = [None] * 7 # Initialize variables 
        try: # Attempt to scrape relevant data
            status = driver.find_element_by_class_name('request-status-label').text.strip() # Request status
            desc = driver.find_element_by_class_name('request-text.row').text # Request description
            date = driver.find_element_by_class_name('request_date').text # Request date
            depts = driver.find_element_by_class_name('current-department').text # Department(s) assigned to the request
            poc = driver.find_element_by_class_name('request-detail').text # Person of contact

            # Messages recorded on the request page, if there are any
            event_titles = get_webelement_text(driver.find_elements_by_class_name('event-title')) # Title for each message
            event_items = get_webelement_text(driver.find_elements_by_class_name('event-item')) # Description for each message
            time_quotes = get_webelement_text(driver.find_elements_by_class_name('time-quotes')) # Time string for each message
            events = pd.DataFrame({ # DataFrame consisting of all messages
                'title': event_titles,
                'item': event_items,
                'time': time_quotes
                })

            # Documents attached to the request, if there are any
            public_docs = driver.find_element_by_id('public-docs') # WebElement containing the documents
            folders = public_docs.find_elements_by_class_name('folder-toggle') # Expand folders, if there are any
            if folders:
                for folder in folders:
                    folder.click()
            doc_links = public_docs.find_elements_by_class_name('document-link') # Links to documents
            docs = pd.DataFrame({ # DataFrame consisting of all documents
                'title': get_webelement_text(doc_links),
                'link': remove_download_from_urls(get_webelement_link(doc_links))
                })
        except NoSuchElementException: # Catch exception thrown if a specific element cannot be found, and silently pass
            pass
        except: # If some other exception occurs, print information about the exception
            print('Unexpected error:', sys.exc_info()[0])
        finally: # Add request to list
            sd_requests.append({
                'request_id': request_id,
                'status': status,
                'request_desc': desc,
                'request_date': date,
                'depts': depts,
                'docs': docs,
                'poc': poc,
                'msgs': events
            })

        sleep(cooldown) # Cooldown between requests
    sleep(cooldown)
        
driver.close()

sd_requests = [x for x in sd_requests if x['status'] is not None] # Remove entries with incomplete information
sd_requests_df = pd.DataFrame(sd_requests) # Convert to DataFrame

# Create a zipped CSV file of the data
compression_opts = dict(method='zip', archive_name='sd_requests.csv')
sd_requests_df.to_csv('data/sd_requests.zip', index=False, compression=compression_opts)
# Out:
# 100%|██████████| 9999/9999 [1:56:31<00:00,  1.43it/s]
# 100%|██████████| 9999/9999 [2:11:04<00:00,  1.27it/s]
#  25%|██▌       | 2511/9999 [1:18:55<4:30:51,  2.17s/it]
# Unexpected error: <class 'ValueError'>
#  26%|██▌       | 2594/9999 [1:21:52<4:25:41,  2.15s/it]
# Unexpected error: <class 'ValueError'>
#  36%|███▌      | 3557/9999 [1:55:31<3:55:16,  2.19s/it]
# Unexpected error: <class 'ValueError'>
#  41%|████      | 4088/9999 [2:12:49<3:17:59,  2.01s/it]
# Unexpected error: <class 'ValueError'>
#  41%|████      | 4089/9999 [2:12:51<3:16:45,  2.00s/it]
# Unexpected error: <class 'ValueError'>
# 100%|██████████| 9999/9999 [2:52:11<00:00,  1.03s/it]
#   2%|▏         | 221/9999 [04:42<6:16:30,  2.31s/it]
# Unexpected error: <class 'ValueError'>
#   3%|▎         | 287/9999 [07:15<6:08:44,  2.28s/it]
# Unexpected error: <class 'ValueError'>
#  12%|█▏        | 1191/9999 [38:15<5:02:13,  2.06s/it]
# Unexpected error: <class 'ValueError'>
#  14%|█▍        | 1377/9999 [44:38<4:44:09,  1.98s/it]
# Unexpected error: <class 'ValueError'>
#  39%|███▉      | 3899/9999 [2:09:26<3:30:22,  2.07s/it]
# Unexpected error: <class 'ValueError'>
#  41%|████      | 4078/9999 [2:15:41<3:14:39,  1.97s/it]
# Unexpected error: <class 'ValueError'>
# 100%|██████████| 9999/9999 [3:39:56<00:00,  1.32s/it]
# 100%|██████████| 9999/9999 [3:32:01<00:00,  1.27s/it]
#   6%|▋         | 647/9999 [18:59<5:26:05,  2.09s/it]

# %%
sd_requests = [x for x in sd_requests if x['status'] is not None] # Remove entries with incomplete information
sd_requests_df = pd.DataFrame(sd_requests) # Convert to DataFrame
sd_requests_df
# Out:
#    request_id  status                                       request_desc  \
# 0        16-1  CLOSED         November 2015 revenue report for SeaWorld.
# 1        16-2  CLOSED  Monthly lease payment information for SeaWorld...
# 2        16-3  CLOSED  Updated version of historical lease payments m...
# 3        16-4  CLOSED        Schedule of Mission Bay Park Lease Revenue.
# 4        16-5  CLOSED  October and November 2015 revenue reports for ...
# 5        16-6  CLOSED  Body camera video recorded from the body camer...
# 6        16-7  CLOSED  Homicide and shooting statistics for 2014 and ...
# 7        16-8  CLOSED  Preliminary comments from the respective fish ...
# 8        16-9  CLOSED  Body camera and other video, audio or still ph...
# 9       16-10  CLOSED  911 call reports for 10/28/2015, between 10-12...
# 10      16-11  CLOSED  Police reports, department records, witness st...
# 11      16-12  CLOSED  Commercial real estate leases and property cur...
# 12      16-13  CLOSED  List of material costs spent for golf resident...
# 13      16-14  CLOSED  Accounting of uncashed checks/warrants, tax ov...
# 14      16-15  CLOSED         Payment made by SeaWorld for November rent
# 15      16-16  CLOSED  SeaWorld revenue report containing monthly ren...
# 16      16-17  CLOSED  SeaWorld lease payments reports for the months...
# 17      16-18  CLOSED  Resolutions, escrow instructions, closing stat...
# 18      16-19  CLOSED  Investigation notes and conclusion regarding 6...
# 19      16-20  CLOSED                Police permit for Palomar Card Club
# 20      16-21  CLOSED  Hazardous materials/waste and underground/abov...
# 21      16-22  CLOSED                 Appraisals related to Belmont Park
# 22      16-23  CLOSED  Building/zoning/fire code violations, ordiannc...
# 23      16-24  CLOSED  Hazardous material inspections, inventories, a...
# 24      16-25  CLOSED  Notices of violation/comply, fire inspection r...
# 25      16-26  CLOSED  Incident related to Lamberto Memije de los San...
# 26      16-27  CLOSED  Emails, writings, phone calls, recordings, inq...
# 27      16-28  CLOSED  Lease revenue for SeaWorld for the month of No...
# 28      16-29  CLOSED  Amount of overtime spent by city staff from al...
# 29      16-30  CLOSED  Force options used and their effectiveness for...
# 30      16-31  CLOSED                            Report from Case#229168
# 31      16-32  CLOSED  Building permits, inspection reports and plann...
# 32      16-33  CLOSED  Data from storm water culvert inspections for ...
# 33      16-34  CLOSED  Communications including, but not limited to, ...
# 34      16-35  CLOSED  Logs or other history of inspections, service ...
# 35      16-36  CLOSED  Hazardous material inspections, inventories, r...
# 36      16-37  CLOSED  All Special Use Permits for tennis and tennis-...
# 37      16-38  CLOSED   Monthly lease payments by by SeaWorld since 2010
# 38      16-39  CLOSED  Statement of Account-Unpaid Checks report and ...
# 39      16-40  CLOSED    Duplicate of PRA request processed as 2015-1950
# 40      16-41  CLOSED  Certified payroll records, fringe benfit state...
# 41      16-42  CLOSED  Sub-contractors list for Catalina 12 Inch Cast...
# 42      16-43  CLOSED  Certified payroll records and fringe benefit s...
# 43      16-44  CLOSED  Payroll reports, fringe benefit statements, no...
# 44      16-45  CLOSED  Payments made in the amount of $10,000 or more...
# 45      16-46  CLOSED  Spreadsheet listing all guns recovered by Poli...
# 46      16-47  CLOSED  Form prepared by TSW related to storm drain as...
# 47      16-48  CLOSED  Monthly lease payments by SeaWorld for Novembe...
# 48      16-49  CLOSED  Authorizing the Golf Divisiion of the Park & R...
# 49      16-50  CLOSED  All police reports filed in the past 10 years ...
# 50      16-51  CLOSED  Documents provided by the respective Fish and ...
# 51      16-52  CLOSED  Information related to firefighter employment ...
# 52      16-53  CLOSED  General contractor/sub-contractor/Multiple Pri...
# 53      16-54  CLOSED  Certificates of occupancy; outstanding/open bu...
# 54      16-55  CLOSED  Documents of City Attorney, Clerk and all coun...
# 55      16-56  CLOSED  Most recent version of the monthly revenue rep...
#
#                  request_date  \
# 0     January 4, 2016 via web
# 1     January 4, 2016 via web
# 2     January 4, 2016 via web
# 3     January 4, 2016 via web
# 4     January 4, 2016 via web
# 5     January 4, 2016 via web
# 6     January 4, 2016 via web
# 7   December 29, 2015 via web
# 8     January 4, 2016 via web
# 9     January 4, 2016 via web
# 10    January 4, 2016 via web
# 11    January 4, 2016 via web
# 12    January 4, 2016 via web
# 13    January 5, 2016 via web
# 14    January 5, 2016 via web
# 15    January 5, 2016 via web
# 16    January 5, 2016 via web
# 17    January 5, 2016 via web
# 18    January 5, 2016 via web
# 19    January 5, 2016 via web
# 20    January 5, 2016 via web
# 21    January 6, 2016 via web
# 22    January 6, 2016 via web
# 23    January 6, 2016 via web
# 24    January 6, 2016 via web
# 25  November 23, 2015 via web
# 26    January 7, 2016 via web
# 27    January 7, 2016 via web
# 28    January 7, 2016 via web
# 29    January 7, 2016 via web
# 30    January 8, 2016 via web
# 31    January 8, 2016 via web
# 32    January 8, 2016 via web
# 33    January 8, 2016 via web
# 34    January 7, 2016 via web
# 35    January 8, 2016 via web
# 36    January 8, 2016 via web
# 37   January 11, 2016 via web
# 38   January 11, 2016 via web
# 39  December 30, 2015 via web
# 40   January 12, 2016 via web
# 41   January 12, 2016 via web
# 42   January 12, 2016 via web
# 43   January 12, 2016 via web
# 44   January 12, 2016 via web
# 45   January 12, 2016 via web
# 46   January 12, 2016 via web
# 47   January 12, 2016 via web
# 48   January 12, 2016 via web
# 49   January 12, 2016 via web
# 50    January 6, 2016 via web
# 51   January 12, 2016 via web
# 52   January 12, 2016 via web
# 53   January 13, 2016 via web
# 54   January 13, 2016 via web
# 55   January 13, 2016 via web
#
#                                                depts  \
# 0   Department of Real Estate and Airport Management
# 1   Department of Real Estate and Airport Management
# 2   Department of Real Estate and Airport Management
# 3   Department of Real Estate and Airport Management
# 4   Department of Real Estate and Airport Management
# 5                      Public Records Administration
# 6                      Public Records Administration
# 7                                 Parks & Recreation
# 8                      Public Records Administration
# 9                                             Police
# 10                                            Police
# 11  Department of Real Estate and Airport Management
# 12                                Parks & Recreation
# 13
# 14  Department of Real Estate and Airport Management
# 15  Department of Real Estate and Airport Management
# 16  Department of Real Estate and Airport Management
# 17  Department of Real Estate and Airport Management
# 18                                  Code Enforcement
# 19                     Public Records Administration
# 20                            Environmental Services
# 21  Department of Real Estate and Airport Management
# 22                              Development Services
# 23                            Environmental Services
# 24                                  Code Enforcement
# 25                                     City Attorney
# 26                                  Code Enforcement
# 27  Department of Real Estate and Airport Management
# 28                     Public Records Administration
# 29                     Public Records Administration
# 30                                  Code Enforcement
# 31                     Public Records Administration
# 32                     Public Records Administration
# 33                     Public Records Administration
# 34                     Public Records Administration
# 35                            Environmental Services
# 36                                Parks & Recreation
# 37  Department of Real Estate and Airport Management
# 38                                    City Treasurer
# 39                     Public Records Administration
# 40                     Equal Opportunity Contracting
# 41                  Engineering and Capital Projects
# 42                     Equal Opportunity Contracting
# 43                     Equal Opportunity Contracting
# 44
# 45                     Public Records Administration
# 46                                    Transportation
# 47  Department of Real Estate and Airport Management
# 48                                Parks & Recreation
# 49                     Public Records Administration
# 50                                Parks & Recreation
# 51                     Public Records Administration
# 52                          Purchasing & Contracting
# 53                                  Code Enforcement
# 54                                     City Attorney
# 55  Department of Real Estate and Airport Management
#
#                                                  docs                     poc  \
# 0                                           title ...         Jeffrey Wallace
# 1    Empty DataFrame
# Columns: [title, link]
# Index: []         Jeffrey Wallace
# 2    Empty DataFrame
# Columns: [title, link]
# Index: []         Jeffrey Wallace
# 3                                                 ...         Jeffrey Wallace
# 4    Empty DataFrame
# Columns: [title, link]
# Index: []         Jeffrey Wallace
# 5    Empty DataFrame
# Columns: [title, link]
# Index: []      Lea Fields-Bernard
# 6    Empty DataFrame
# Columns: [title, link]
# Index: []      Lea Fields-Bernard
# 7                                                 ...            Adrian Zolla
# 8    Empty DataFrame
# Columns: [title, link]
# Index: []      Lea Fields-Bernard
# 9    Empty DataFrame
# Columns: [title, link]
# Index: []      Humberto Hernandez
# 10                         title  \
# 0  Abbruscato_...      Humberto Hernandez
# 11                           title  \
# 0  PRA - RE ...         Jeffrey Wallace
# 12                              title  \
# 0  CCPRA ...              Gina Dulay
# 13                                                ...              Doug Enger
# 14   Empty DataFrame
# Columns: [title, link]
# Index: []         Jeffrey Wallace
# 15   Empty DataFrame
# Columns: [title, link]
# Index: []         Jeffrey Wallace
# 16                                          title ...         Jeffrey Wallace
# 17   Empty DataFrame
# Columns: [title, link]
# Index: []         Jeffrey Wallace
# 18                                       title  \
# ...        Ginger Rodriguez
# 19                                    title  \
# 0  ...      Lea Fields-Bernard
# 20   Empty DataFrame
# Columns: [title, link]
# Index: []             Alan Pitell
# 21   Empty DataFrame
# Columns: [title, link]
# Index: []         Jeffrey Wallace
# 22                                   title  \
# 0  C...        Ginger Rodriguez
# 23   Empty DataFrame
# Columns: [title, link]
# Index: []             Alan Pitell
# 24                                           title...        Ginger Rodriguez
# 25                                            titl...           Nancy Shapiro
# 26   Empty DataFrame
# Columns: [title, link]
# Index: []        Ginger Rodriguez
# 27   Empty DataFrame
# Columns: [title, link]
# Index: []         Jeffrey Wallace
# 28                                     title  \
# 0 ...      Lea Fields-Bernard
# 29                               title  \
# 0  2014-...      Lea Fields-Bernard
# 30                    title                       ...        Ginger Rodriguez
# 31                                          title ...      Lea Fields-Bernard
# 32                              title  \
# 0  CCPRA ...           Roger Wammack
# 33                                    title  \
# 0  ...      Lea Fields-Bernard
# 34   Empty DataFrame
# Columns: [title, link]
# Index: []            Chris Gascon
# 35   Empty DataFrame
# Columns: [title, link]
# Index: []             Alan Pitell
# 36                                                ...              Gina Dulay
# 37                  title                         ...         Jeffrey Wallace
# 38   Empty DataFrame
# Columns: [title, link]
# Index: []             Elena Perez
# 39   Empty DataFrame
# Columns: [title, link]
# Index: []      Lea Fields-Bernard
# 40                                                ...            Cheryl Smoot
# 41                                                ...              Al Rechany
# 42   Empty DataFrame
# Columns: [title, link]
# Index: []            Cheryl Smoot
# 43   Empty DataFrame
# Columns: [title, link]
# Index: []         Christian Silva
# 44                                 title  \
# 0  PRA...             Elena Perez
# 45                           title  \
# 0  Gun Expor...      Lea Fields-Bernard
# 46                               title  \
# 0  GOVON...      Rosemary McCartney
# 47                                 title  \
# 0  Rev...         Jeffrey Wallace
# 48   Empty DataFrame
# Columns: [title, link]
# Index: []              Gina Dulay
# 49                                                ...      Lea Fields-Bernard
# 50   Empty DataFrame
# Columns: [title, link]
# Index: []              Gina Dulay
# 51   Empty DataFrame
# Columns: [title, link]
# Index: []      Lea Fields-Bernard
# 52   Empty DataFrame
# Columns: [title, link]
# Index: []  Stacy Roberts-Gilhooly
# 53                                                ...        Ginger Rodriguez
# 54                                                ...           Nancy Shapiro
# 55   Empty DataFrame
# Columns: [title, link]
# Index: []         Jeffrey Wallace
#
#                                                  msgs
# 0                              title  \
# 0         ...
# 1                              title  \
# 0         ...
# 2                              title  \
# 0         ...
# 3                              title  \
# 0         ...
# 4                              title  \
# 0         ...
# 5                              title  \
# 0  Request...
# 6                              title  \
# 0         ...
# 7                               title  \
# 0        ...
# 8                              title  \
# 0  Request...
# 9                              title  \
# 0  Request...
# 10                              title  \
# 0   Reque...
# 11                             title  \
# 0         ...
# 12                             title  \
# 0         ...
# 13                             title  \
# 0  Request...
# 14                             title  \
# 0         ...
# 15                             title  \
# 0         ...
# 16                             title  \
# 0         ...
# 17                             title  \
# 0         ...
# 18                             title  \
# 0         ...
# 19                             title  \
# 0         ...
# 20                             title  \
# 0         ...
# 21                             title  \
# 0         ...
# 22                             title  \
# 0         ...
# 23                             title  \
# 0         ...
# 24                              title  \
# 0        ...
# 25                              title  \
# 0   Reque...
# 26                             title  \
# 0         ...
# 27                             title  \
# 0         ...
# 28                              title  \
# 0        ...
# 29                             title  \
# 0         ...
# 30                             title  \
# 0         ...
# 31                             title  \
# 0         ...
# 32                             title  \
# 0  Request...
# 33                              title  \
# 0   Reque...
# 34                             title  \
# 0         ...
# 35                             title  \
# 0         ...
# 36                              title  \
# 0        ...
# 37                             title  \
# 0         ...
# 38                             title  \
# 0         ...
# 39                             title  \
# 0         ...
# 40                             title  \
# 0         ...
# 41                             title  \
# 0         ...
# 42                             title  \
# 0         ...
# 43                             title              ...
# 44                             title  \
# 0         ...
# 45                             title  \
# 0         ...
# 46                             title  \
# 0         ...
# 47                             title  \
# 0         ...
# 48                             title  \
# 0         ...
# 49                             title  \
# 0  Request...
# 50                             title  \
# 0         ...
# 51                             title  \
# 0         ...
# 52                             title  \
# 0         ...
# 53                             title  \
# 0         ...
# 54                             title  \
# 0  Request...
# 55                             title  \
# 0         ...

# %%
# Create a zipped CSV file of the data
compression_opts = dict(method='zip', archive_name='sd_requests.csv')
sd_requests_df.to_csv('data/sd_requests.zip', index=False, compression=compression_opts)

# %%
# Create a list showing whether a given request was scraped or not (does not account for requests that do not exist or are inaccessible)
unscraped_requests = [request_id for request_id in request_ids if request_id in sd_requests_df['request_id'].to_numpy()]
len(unscraped_requests)

# %%
driver = webdriver.Firefox(options=options)
missing_requests = []

for request_id in unscraped_requests:
    url = urls[i] + request_id
    driver.get(url)
    
    if (request_id not in driver.title):
        sleep(cooldown)
        continue
    
    try:
        driver.find_element_by_class_name('request-status-label')
    except NoSuchElementException:
        continue
    
    missing_requests.append(request_id)
    sleep(cooldown)
    
driver.close()

# %%
# Scraper functions
def scrape_record(url, request_id):
    '''
    Scrapes data about a given request on a NextRequest request database. For use with parallelization.
    '''
    driver = webdriver.Remote(desired_capabilities=DesiredCapabilities.FIREFOX, options=options)
    driver.get(url + request_id) # Attempt to access the record
    
    # If the record does not exist, return nothing
    if (request_id not in driver.title):
        return
    
    status, desc, date, depts, docs, poc, events = [None] * 7 # Initialize variables 
    try: # Attempt to scrape relevant data
        status = driver.find_element_by_class_name('request-status-label').text.strip() # Request status
        desc = driver.find_element_by_class_name('request-text.row').text # Request description
        date = driver.find_element_by_class_name('request_date').text # Request date
        depts = driver.find_element_by_class_name('current-department').text # Department(s) assigned to the request
        poc = driver.find_element_by_class_name('request-detail').text # Person of contact

        # Messages recorded on the request page, if there are any
        event_titles = get_webelement_text(driver.find_elements_by_class_name('event-title')) # Title for each message
        event_items = get_webelement_text(driver.find_elements_by_class_name('event-item')) # Description for each message
        time_quotes = get_webelement_text(driver.find_elements_by_class_name('time-quotes')) # Time string for each message
        events = pd.DataFrame({ # DataFrame consisting of all messages
            'title': event_titles,
            'item': event_items,
            'time': time_quotes
            })
        
        # Documents attached to the request, if there are any
        public_docs = driver.find_element_by_id('public-docs') # WebElement containing the documents
        folders = public_docs.find_elements_by_class_name('folder-toggle') # Expand folders, if there are any
        if folders:
            for folder in folders:
                folder.click()
        doc_links = public_docs.find_elements_by_class_name('document-link') # Links to documents
        docs = pd.DataFrame({ # DataFrame consisting of all documents
            'title': get_webelement_text(doc_links),
            'link': remove_download_from_urls(get_webelement_link(doc_links))
            })
    except NoSuchElementException: # Catch exception thrown if a specific element cannot be found, and silently pass
        pass
    except: # If some other exception occurs, print information about the exception
        print('Unexpected error:', sys.exc_info()[0])
    finally: # Return the request
        driver.close()

        return {
            'request_id': request_id,
            'status': status,
            'request_desc': desc,
            'request_date': date,
            'depts': depts,
            'docs': docs,
            'poc': poc,
            'msgs': events
            }
    
def get_city_from_url(url):
    '''
    Finds the city name from the NextRequest URL.
    '''
    return re.match(r'(?<=https://)[a-zA-Z]*', url)[0]

def get_webelement_text(webelement):
    '''
    Gets the text of each web element in a list, if such a list exists.
    '''
    return list(map(lambda x: x.text, webelement)) if (webelement is not None and webelement) else None

def get_webelement_link(webelement):
    '''
    Gets the link of each web element in a list, if such a list exists.
    '''
    return list(map(lambda x: x.get_attribute('href'), webelement)) if (webelement is not None and webelement) else None

def remove_download_from_urls(urls):
    '''
    Removes '/download' from the end of a list of URLs, if the list exists.
    '''
    return list(map(lambda url: re.match(r'.*(?=/download)', url)[0], urls)) if (urls is not None and urls) else None

# %%
# # Test remote WebDriver (run Selenium Grid instance locally before running this cell)
# driver = webdriver.Remote(desired_capabilities=DesiredCapabilities.FIREFOX, options=options)
# driver.get('http://www.google.com')
# driver.close()

# %%
# # Test to make sure the driver works
# 
# driver = webdriver.Firefox(options=options) # Instantiate a headless Firefox WebDriver
# for url in urls:
#     driver.get(url)
#     print(driver.title)
#     sleep(5)
    
# driver.close()

# %%
# %%timeit
# # Test for retrieving message info from a specific request
# driver = webdriver.Firefox(options=options)
# driver.get('https://sandiego.nextrequest.com/requests/21-4915')
# print(driver.title)

# event_titles = driver.find_elements_by_class_name('event-title')
# event_items = driver.find_elements_by_class_name('event-item')
# times = driver.find_elements_by_class_name('time-quotes')
# for title, item, time in list(zip(event_titles, event_items, times)):
#     print(title.text)
#     print(item.text)
#     print(time.text)
#     print()

# driver.close()

# %%
# # Scraping documents test
# driver = webdriver.Firefox(options=options)

# for request_id in [5369, 5313, 5374]:
#     url = 'https://sandiego.nextrequest.com/requests/21-' + str(request_id)
#     driver.get(url)

#     docs = driver.find_element_by_id('public-docs')
#     folders = docs.find_elements_by_class_name('folder-toggle')
#     if folders:
#         for folder in folders:
#             folder.click()
#     else:
#         print('No folders found for', request_id)
    
#     doc_links = docs.find_elements_by_class_name('document-link')
#     display(
#         pd.DataFrame(
#             list(zip(get_webelement_text(doc_links), remove_download_from_urls(get_webelement_link(doc_links)))),
#             columns=['title', 'link']
#         )
#     )
#     display(
#         pd.DataFrame({
#             'title': get_webelement_text(doc_links),
#             'link': remove_download_from_urls(get_webelement_link(doc_links))
#         })
#     )

# driver.close()

# %%
# Parallelized script
scrape_request = lambda i: scrape_record(urls[0], i)
sd_requests = Parallel(n_jobs=-1, prefer='threads', verbose=10)(delayed(scrape_request)(request_id) for request_id in request_ids)
# Out:
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:   33.9s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-41-cfcd83411d8e> in <module>
#       1 # Parallelized script
#       2 scrape_request = lambda i: scrape_record(urls[0], i)
# ----> 3 sd_requests = Parallel(n_jobs=-1, prefer='threads', verbose=10)(delayed(scrape_request)(request_id) for request_id in request_ids)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/joblib/parallel.py in __call__(self, iterable)
#    1052
#    1053             with self._backend.retrieval_context():
# -> 1054                 self.retrieve()
#    1055             # Make sure that we get a last message telling us we are done
#    1056             elapsed_time = time.time() - self._start_time
#
# ~/opt/anaconda3/lib/python3.8/site-packages/joblib/parallel.py in retrieve(self)
#     931             try:
#     932                 if getattr(self._backend, 'supports_timeout', False):
# --> 933                     self._output.extend(job.get(timeout=self.timeout))
#     934                 else:
#     935                     self._output.extend(job.get())
#
# ~/opt/anaconda3/lib/python3.8/multiprocessing/pool.py in get(self, timeout)
#     763
#     764     def get(self, timeout=None):
# --> 765         self.wait(timeout)
#     766         if not self.ready():
#     767             raise TimeoutError
#
# ~/opt/anaconda3/lib/python3.8/multiprocessing/pool.py in wait(self, timeout)
#     760
#     761     def wait(self, timeout=None):
# --> 762         self._event.wait(timeout)
#     763
#     764     def get(self, timeout=None):
#
# ~/opt/anaconda3/lib/python3.8/threading.py in wait(self, timeout)
#     556             signaled = self._flag
#     557             if not signaled:
# --> 558                 signaled = self._cond.wait(timeout)
#     559             return signaled
#     560
#
# ~/opt/anaconda3/lib/python3.8/threading.py in wait(self, timeout)
#     300         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     301             if timeout is None:
# --> 302                 waiter.acquire()
#     303                 gotit = True
#     304             else:
#
# KeyboardInterrupt:
