# %%
from selenium import webdriver
from selenium.webdriver.firefox.options import Options

options = Options()
options.headless = True

# %%
driver = webdriver.Firefox(options=options)
driver.get('https://pythonbasics.org')
print (driver.page_source)
driver.quit()

# %%
import pandas as pd
import zipfile

# %%
vallejo = pd.read_csv(zipfile.ZipFile('data/vallejo_requests.zip', 'r').open('vallejo_requests.csv'))
vallejo
# Out:
#           id  status                                               desc  \
# 0       16-1  CLOSED  I need my birth record and if possible open my...
# 1       16-3  CLOSED  Address:\n408 Tennessee Street, Vallejo, CA 94...
# 2      16-15  CLOSED  A log of records requests submitted to the cit...
# 3      16-16  CLOSED  RE:\nThe Ridge Townhomes\n301 Fairgrounds Driv...
# 4      16-17  CLOSED  Under the FOIA, I want to ask for any staff re...
# ...      ...     ...                                                ...
# 3999  22-380  CLOSED  Hello,\nMy company is doing a Phase 1 Environm...
# 4000  22-381    OPEN  Hello,\nMy company is doing a Phase 1 Environm...
# 4001  22-384    OPEN  Hi,\nPlease provide me the information of open...
# 4002  22-386  CLOSED  Warning Notice and the inspection photos for a...
# 4003  22-387  CLOSED  Notices and the inspection photos for case #CE...
#
#                          date                  depts  \
# 0       April 5, 2016 via web    City Clerk’s Office
# 1      April 27, 2016 via web                    NaN
# 2        May 19, 2016 via web          None Assigned
# 3        May 23, 2016 via web                    NaN
# 4      May 20, 2016 via email                    NaN
# ...                       ...                    ...
# 3999    April 5, 2022 via web                    NaN
# 4000    April 5, 2022 via web    City Clerk’s Office
# 4001    April 6, 2022 via web  All Other Departments
# 4002  April 6, 2022 via email       Code Enforcement
# 4003  April 6, 2022 via email       Code Enforcement
#
#                                                    docs  \
# 0                                                   NaN
# 1     title,link\nPERMITS FOR 408 TENNESSEE STREET.d...
# 2     title,link\n2012 Public Records Request log.pd...
# 3     title,link\nSD02-0033 Site Map.pdf,https://val...
# 4     title,link\nVMT Lease Agreement (Amendment 3)....
# ...                                                 ...
# 3999                                                NaN
# 4000                                                NaN
# 4001  title,link\n1233 Locust_Permit Summary.xls,htt...
# 4002  title,link\n742 TENNESSEE PHOTOS.pdf,https://v...
# 4003  title,link\n742 TENNESSEE PHOTOS.pdf,https://v...
#
#                                            poc  \
# 0                  Dawn Abrahamson, City Clerk
# 1                      Livian Ellis, Secretary
# 2                  Dawn Abrahamson, City Clerk
# 3          Leslie Trybull, Executive Secretary
# 4     Angelina Abella, Administrative Clerk II
# ...                                        ...
# 3999                             Angela Knight
# 4000               Dawn Abrahamson, City Clerk
# 4001               Dawn Abrahamson, City Clerk
# 4002                      Karen Ang, Secretary
# 4003                      Karen Ang, Secretary
#
#                                                    msgs
# 0     title,item,time\n"Request Closed   Hide\nPubli...
# 1     title,item,time\n"Request Closed\nPublic","Rec...
# 2     title,item,time\n"Request Closed\nPublic","Re-...
# 3     title,item,time\n"Request Closed   Hide\nPubli...
# 4     title,item,time\n"Request Closed   Hide\nPubli...
# ...                                                 ...
# 3999  title,item,time\n"Request Closed   Hide\nPubli...
# 4000  title,item,time\n"Request Published\nPublic",,...
# 4001  title,item,time\n"Document(s) Released\nPublic...
# 4002  title,item,time\n"Request Closed\nPublic","We ...
# 4003  title,item,time\n"Request Closed\nPublic","We ...
#
# [4004 rows x 8 columns]
