# %% [markdown]
# # NextRequest data cleaning and EDA
# *Author: Steven Yuan*
#
# This notebook contains potentially useful data cleaning and EDA routines for scraped NextRequest data.

# %%
import pandas as pd
from io import StringIO
import zipfile

from nextrequest_eda_utils import *

# %%
sd = pd.read_csv(zipfile.ZipFile('../data/sd_requests.zip', 'r').open('sd_requests.csv'))
sd.head()
# Out:
#         id  status                                               desc  \
# 0  15-1810  CLOSED  Notices of Violation/Notice to Comply, fire in...
# 1  15-1811  CLOSED       The October 2015 monthly report for SeaWorld
# 2  15-1812  CLOSED  Records related to the following BIDS:  Adams ...
# 3  15-1813  CLOSED  Historical lease payments made by SeaWorld to ...
# 4  15-1814  CLOSED  Open violations, variances, ordinances, approv...
#
#                        date                                             depts  \
# 0  December 7, 2015 via web                                  Code Enforcement
# 1  December 7, 2015 via web  Department of Real Estate and Airport Management
# 2  December 7, 2015 via web                                        City Clerk
# 3  December 7, 2015 via web  Department of Real Estate and Airport Management
# 4  December 7, 2015 via web                                  Code Enforcement
#
#                                                 docs                 poc  \
# 0  title,link\n5040 ShorehamPlace building permit...    Ginger Rodriguez
# 1                                                NaN     Jeffrey Wallace
# 2  title,link\nhttp://www.sandiego.gov/park-and-r...  Mailei Ross-Cerezo
# 3                                                NaN     Jeffrey Wallace
# 4  title,link\nSite Plan - 11943 El Camino Real.p...    Ginger Rodriguez
#
#                                                 msgs
# 0  title,item,time\n"Request Closed\nPublic",02. ...
# 1  title,item,time\n"Request Published\nPublic",,...
# 2  title,item,time\n"Request Closed\nPublic",Stil...
# 3  title,item,time\n"Request Closed\nPublic",02. ...
# 4  title,item,time\n"Request Closed\nPublic",02. ...

# %%
sd_clean.shape[0] # Number of requests scraped
# Out:
# 28848

# %%
sd_clean = nextrequest_df_clean(sd, debug=True)
# Out:
# fillna complete
# docs_df complete
# msgs_df complete
# date-via split complete
# time-by split in msgs complete

# %%
sd_clean.head()
# Out:
#         id  status                                               desc  \
# 0  15-1810  CLOSED  Notices of Violation/Notice to Comply, fire in...
# 1  15-1811  CLOSED       The October 2015 monthly report for SeaWorld
# 2  15-1812  CLOSED  Records related to the following BIDS:  Adams ...
# 3  15-1813  CLOSED  Historical lease payments made by SeaWorld to ...
# 4  15-1814  CLOSED  Open violations, variances, ordinances, approv...
#
#                                               depts  \
# 0                                  Code Enforcement
# 1  Department of Real Estate and Airport Management
# 2                                        City Clerk
# 3  Department of Real Estate and Airport Management
# 4                                  Code Enforcement
#
#                                                 docs                 poc  \
# 0  title,link
# 5040 ShorehamPlace building permits...    Ginger Rodriguez
# 1                                                        Jeffrey Wallace
# 2  title,link
# http://www.sandiego.gov/park-and-re...  Mailei Ross-Cerezo
# 3                                                        Jeffrey Wallace
# 4  title,link
# Site Plan - 11943 El Camino Real.pd...    Ginger Rodriguez
#
#                                                 msgs  \
# 0  title,item,time
# "Request Closed
# Public",02. Re...
# 1  title,item,time
# "Request Published
# Public",,"D...
# 2  title,item,time
# "Request Closed
# Public",Still ...
# 3  title,item,time
# "Request Closed
# Public",02. Re...
# 4  title,item,time
# "Request Closed
# Public",02. Re...
#
#                                              docs_df  \
# 0                                       title  \
# ...
# 1
# 2                                                ...
# 3
# 4                                    title  \
# 0  ...
#
#                                              msgs_df              date  \
# 0                            title               ...  December 7, 2015
# 1                            title               ...  December 7, 2015
# 2                            title  \
# 0         R...  December 7, 2015
# 3                            title               ...  December 7, 2015
# 4                             title              ...  December 7, 2015
#
#        via    date_dt
# 0  via web 2015-12-07
# 1  via web 2015-12-07
# 2  via web 2015-12-07
# 3  via web 2015-12-07
# 4  via web 2015-12-07

# %%
sd_clean.loc[4]['msgs_df']
# Out:
#                            title                                  item  \
# 0          Request Closed
# Public                          02. Released
# 1    Document(s) Released
# Public  Site Plan - 11943 El Camino Real.pdf
# 2        Request Reopened
# Public
# 3          Request Closed
# Public                          02. Released
# 4    Document(s) Released
# Public           15-1814 Fire Responsive.pdf
# 5        Request Reopened
# Public
# 6          Request Closed
# Public                          02. Released
# 7        Request Reopened
# Public
# 8          Request Closed
# Public                          02. Released
# 9          Request Closed
# Public                          02. Released
# 10   Document(s) Released
# Public  Site Plan - 11943 El Camino Real.pdf
# 11      Request Published
# Public
# 12         Request Opened
# Public              Request received via web
# 13  Department Assignment
# Public                      Code Enforcement
# 14      Request Published
# Public
#
#                           time  \
# 0   December 24, 2015, 10:34am
# 1   December 24, 2015, 10:33am
# 2   December 24, 2015, 10:32am
# 3    December 24, 2015, 8:09am
# 4    December 24, 2015, 8:09am
# 5    December 24, 2015, 8:02am
# 6    December 17, 2015, 4:00pm
# 7    December 17, 2015, 3:56pm
# 8    December 17, 2015, 3:54pm
# 9    December 17, 2015, 3:52pm
# 10   December 17, 2015, 3:51pm
# 11    December 8, 2015, 9:20am
# 12    December 7, 2015, 5:39pm
# 13    December 7, 2015, 5:39pm
# 14    December 7, 2015, 5:39pm
#
#                                                    by             time_dt
# 0                                    Ginger Rodriquez 2015-12-24 10:34:00
# 1                                    Ginger Rodriquez 2015-12-24 10:33:00
# 2                                    Ginger Rodriquez 2015-12-24 10:32:00
# 3                                    Ginger Rodriquez 2015-12-24 08:09:00
# 4                                    Ginger Rodriquez 2015-12-24 08:09:00
# 5                       Amanda Alvarado, Senior Clerk 2015-12-24 08:02:00
# 6                                    Ginger Rodriquez 2015-12-17 16:00:00
# 7                                    Ginger Rodriquez 2015-12-17 15:56:00
# 8                                    Ginger Rodriquez 2015-12-17 15:54:00
# 9                                    Ginger Rodriquez 2015-12-17 15:52:00
# 10                                   Ginger Rodriquez 2015-12-17 15:51:00
# 11  Lea Fields-Bernard, Public Records Administrat... 2015-12-08 09:20:00
# 12  Lea Fields-Bernard, Public Records Administrat... 2015-12-07 17:39:00
# 13                                                    2015-12-07 17:39:00
# 14                                                    2015-12-07 17:39:00

# %%
# Query for info about a specific request
request_id = '"17-22"'
sd_clean.query('id == ' + request_id).iloc[0]['msgs_df']
# Out:
#                              title  \
# 0         Request Published
# Public
# 1            Request Closed
# Public
# 2      Document(s) Released
# Public
# 3      Document(s) Released
# Public
# 4      Document(s) Released
# Public
# ...                            ...
# 1112   Document(s) Released
# Public
# 1113   Document(s) Released
# Public
# 1114   Document(s) Released
# Public
# 1115  Department Assignment
# Public
# 1116         Request Opened
# Public
#
#                                                    item  \
# 0
# 1     02. Released
# All responsive documents have bee...
# 2                                   20160315_131321.jpg
# 3                                   20160315_131307.jpg
# 4                                   20160315_131230.jpg
# ...                                                 ...
# 1112                                20160307_155141.jpg
# 1113                                20160307_155139.jpg
# 1114                     7411 Hillside Drive Photos.pdf
# 1115                                   Code Enforcement
# 1116                           Request received via web
#
#                           time  \
# 0     January 16, 2017, 4:10pm
# 1     January 13, 2017, 4:06pm
# 2     January 13, 2017, 4:00pm
# 3     January 13, 2017, 4:00pm
# 4     January 13, 2017, 4:00pm
# ...                        ...
# 1112  January 13, 2017, 3:54pm
# 1113  January 13, 2017, 3:54pm
# 1114  January 13, 2017, 3:54pm
# 1115   January 6, 2017, 3:23pm
# 1116  January 4, 2017, 10:08am
#
#                                                      by             time_dt
# 0                                                       2017-01-16 16:10:00
# 1                                      Ginger Rodriquez 2017-01-13 16:06:00
# 2                                      Ginger Rodriquez 2017-01-13 16:00:00
# 3                                      Ginger Rodriquez 2017-01-13 16:00:00
# 4                                      Ginger Rodriquez 2017-01-13 16:00:00
# ...                                                 ...                 ...
# 1112                                   Ginger Rodriquez 2017-01-13 15:54:00
# 1113                                   Ginger Rodriquez 2017-01-13 15:54:00
# 1114                                   Ginger Rodriquez 2017-01-13 15:54:00
# 1115  Lea Fields-Bernard, Public Records Administrat... 2017-01-06 15:23:00
# 1116                                                    2017-01-04 10:08:00
#
# [1117 rows x 5 columns]

# %%
# Find request descriptions with the given substring, case insensitive
desc = 'Padres'
test_df[test_df['desc'].str.contains(desc, case=False)]

# %%
# Find requests whose department(s) contain the given substring, case insensitive
dept = 'police'
sd_clean[lambda df: df['depts'].str.contains(dept, case=False)]

# %%
# Which requests had the longest message history? (Useful for finding worst-case scenarios for the scraper)
long_msgs = sd_clean['msgs_df'].apply(lambda df: df.shape[0] if df is not None else 0).sort_values(ascending=False)
long_msgs.head(10)

# %%
# Sort requests by message history length
requests_long_msg = sd_clean.loc[long_msgs.index]
requests_long_msg.head(20)

# %%
# TODO: Extract department assignment additions and removals based on message history
def get_dept_assign(msgs, get_time=False):
    if msgs is None: return None

    dept_assign = msgs[lambda df: df['title'].str.contains('Department')].sort_values(by='time_dt', ignore_index=True)
    
    if dept_assign.empty: return None

    # TODO: Add option to include time information
    dept_assign_init = dept_assign[  # Initial department assignment
            lambda df: ~df['item'].str.contains(r'Added|Removed')
        ]['item'].to_numpy()
    dept_assign_added = dept_assign[  # Departments that were added
            lambda df: df['item'].str.contains('Added')
        ]['item'].str.split(
            r'Added: |Removed: '
        ).str[1].str.strip(' .').str.split(', ').to_numpy()
    dept_assign_removed = dept_assign[  # Departments that were removed
            lambda df: df['item'].str.contains('Removed')
        ]['item'].str.split(
            'Removed: '
        ).str[-1].str.strip(' .').str.split(', ').to_numpy()
    
    return {
        'dept_added': list(set([dept for l in list(dept_assign_added).append(dept_assign_init) for dept in l])),
        'dept_removed': list(set([dept for l in list(dept_assign_removed) for dept in l]))
        }

# %%
testtest = sd_clean['msgs_df'].apply(lambda df: len(df[df['title'].str.contains('Department')])).sort_values(ascending=False)

# %%
testtest.head(20)
# Out:
# 22065    53
# 21905    53
# 7386     50
# 14991    50
# 14983    49
# 14984    47
# 19196    45
# 19496    44
# 14988    44
# 14986    43
# 14166    42
# 14985    40
# 14987    38
# 14989    36
# 26149    30
# 20013    27
# 6398     27
# 5607     26
# 20200    25
# 22047    25
# Name: msgs_df, dtype: int64

# %%
test = sd_clean.loc[0]['msgs_df'][lambda df: df['title'].str.contains('Department')]
aa = test[lambda df: df['item'].str.contains('Removed')]['item'].str.split('Removed: ').str[-1].str.strip('.').str.split(', ').to_numpy()
aaa = list(set([dept for l in list(aa) for dept in l]))
aaa
# Out:
# []

# %%
vallejo = pd.read_csv(zipfile.ZipFile('../data/vallejo_requests.zip', 'r').open('vallejo_requests.csv'))
vallejo.head()
# Out:
#       id  status                                               desc  \
# 0   16-1  CLOSED  I need my birth record and if possible open my...
# 1   16-3  CLOSED  Address:\n408 Tennessee Street, Vallejo, CA 94...
# 2  16-15  CLOSED  A log of records requests submitted to the cit...
# 3  16-16  CLOSED  RE:\nThe Ridge Townhomes\n301 Fairgrounds Driv...
# 4  16-17  CLOSED  Under the FOIA, I want to ask for any staff re...
#
#                      date                depts  \
# 0   April 5, 2016 via web  City Clerk’s Office
# 1  April 27, 2016 via web                  NaN
# 2    May 19, 2016 via web        None Assigned
# 3    May 23, 2016 via web                  NaN
# 4  May 20, 2016 via email                  NaN
#
#                                                 docs  \
# 0                                                NaN
# 1  title,link\nPERMITS FOR 408 TENNESSEE STREET.d...
# 2  title,link\n2012 Public Records Request log.pd...
# 3  title,link\nSD02-0033 Site Map.pdf,https://val...
# 4  title,link\nVMT Lease Agreement (Amendment 3)....
#
#                                         poc  \
# 0               Dawn Abrahamson, City Clerk
# 1                   Livian Ellis, Secretary
# 2               Dawn Abrahamson, City Clerk
# 3       Leslie Trybull, Executive Secretary
# 4  Angelina Abella, Administrative Clerk II
#
#                                                 msgs
# 0  title,item,time\n"Request Closed   Hide\nPubli...
# 1  title,item,time\n"Request Closed\nPublic","Rec...
# 2  title,item,time\n"Request Closed\nPublic","Re-...
# 3  title,item,time\n"Request Closed   Hide\nPubli...
# 4  title,item,time\n"Request Closed   Hide\nPubli...

# %%
vallejo_clean = nextrequest_df_clean(vallejo, debug=True)
# Out:
# fillna complete
# docs_df complete
# msgs_df complete
# date-via split complete
# time-by split in msgs complete

# %%
eeeeee = vallejo_clean['msgs_df'].apply(lambda df: len(df[df['title'].str.contains('Department')])).sort_values(ascending=False)

# %%
vallejo_clean.loc[2197]['msgs_df']
# Out:
#                                       title  \
# 0              Request Closed   Hide
# Public
# 1  Document(s) Released to Requester
# Public
# 2              Department Assignment
# Public
# 3              Department Assignment
# Public
# 4                  Request Published
# Public
# 5              Department Assignment
# Public
# 6              Department Assignment
# Public
# 7                     Request Opened
# Public
#
#                                                 item  \
# 0  We have provided all records responsive to you...
# 1  Mathis Group_Risk Assessments_2.9.2017 through...
# 2  Added: City Clerk’s Office. Removed: Police De...
# 3                          Added: Police Department.
# 4
# 5                    Removed: All Other Departments.
# 6                              All Other Departments
# 7                           Request received via web
#
#                         time                                      by  \
# 0  December 11, 2020, 4:29pm  Dale Miller, Administrative Analyst II
# 1  December 11, 2020, 4:27pm  Dale Miller, Administrative Analyst II
# 2   December 4, 2020, 1:53pm                          Melissa Rhodes
# 3   December 4, 2020, 9:47am             Dawn Abrahamson, City Clerk
# 4  November 23, 2020, 7:20am             Dawn Abrahamson, City Clerk
# 5  November 23, 2020, 7:20am             Dawn Abrahamson, City Clerk
# 6  November 22, 2020, 9:25am
# 7  November 22, 2020, 9:25am
#
#               time_dt
# 0 2020-12-11 16:29:00
# 1 2020-12-11 16:27:00
# 2 2020-12-04 13:53:00
# 3 2020-12-04 09:47:00
# 4 2020-11-23 07:20:00
# 5 2020-11-23 07:20:00
# 6 2020-11-22 09:25:00
# 7 2020-11-22 09:25:00

# %%
eeeeee.head(20)
# Out:
# 2197    4
# 1277    3
# 3468    3
# 1517    3
# 2726    3
# 1127    3
# 1852    3
# 1173    3
# 410     3
# 3384    3
# 829     3
# 3082    3
# 2126    3
# 1181    3
# 1200    3
# 3666    3
# 422     3
# 963     3
# 90      3
# 1092    3
# Name: msgs_df, dtype: int64
