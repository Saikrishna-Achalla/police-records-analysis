# %% [markdown]
# # NextRequest data cleaning and EDA
# *Author: Steven Yuan*
#
# This notebook contains potentially useful data cleaning and EDA routines for scraped NextRequest data.

# %%
import pandas as pd
from io import StringIO
import zipfile

# %%
test_df = pd.read_csv(zipfile.ZipFile('../data/sd_requests.zip', 'r').open('sd_requests.csv'))
test_df.head()
# Out:
#         id  status                                               desc  \
# 0  15-1810  CLOSED  Notices of Violation/Notice to Comply, fire in...
# 1  15-1811  CLOSED       The October 2015 monthly report for SeaWorld
# 2  15-1812  CLOSED  Records related to the following BIDS:  Adams ...
# 3  15-1813  CLOSED  Historical lease payments made by SeaWorld to ...
# 4  15-1814  CLOSED  Open violations, variances, ordinances, approv...
#
#                        date                                             depts  \
# 0  December 7, 2015 via web                                  Code Enforcement
# 1  December 7, 2015 via web  Department of Real Estate and Airport Management
# 2  December 7, 2015 via web                                        City Clerk
# 3  December 7, 2015 via web  Department of Real Estate and Airport Management
# 4  December 7, 2015 via web                                  Code Enforcement
#
#                                                 docs                 poc  \
# 0  title,link\n5040 ShorehamPlace building permit...    Ginger Rodriguez
# 1                                                NaN     Jeffrey Wallace
# 2  title,link\nhttp://www.sandiego.gov/park-and-r...  Mailei Ross-Cerezo
# 3                                                NaN     Jeffrey Wallace
# 4  title,link\nSite Plan - 11943 El Camino Real.p...    Ginger Rodriguez
#
#                                                 msgs
# 0  title,item,time\n"Request Closed\nPublic",02. ...
# 1  title,item,time\n"Request Published\nPublic",,...
# 2  title,item,time\n"Request Closed\nPublic",Stil...
# 3  title,item,time\n"Request Closed\nPublic",02. ...
# 4  title,item,time\n"Request Closed\nPublic",02. ...

# %% [markdown]
# The following process converts the CSV strings in the `docs` and `msgs` columns into DataFrames:

# %%
df_fillna = lambda df: df.convert_dtypes().fillna('') if df is not None else None
test_df = df_fillna(test_df)
test_df
# Out:
#             id  status                                               desc  \
# 0      15-1810  CLOSED  Notices of Violation/Notice to Comply, fire in...
# 1      15-1811  CLOSED       The October 2015 monthly report for SeaWorld
# 2      15-1812  CLOSED  Records related to the following BIDS:  Adams ...
# 3      15-1813  CLOSED  Historical lease payments made by SeaWorld to ...
# 4      15-1814  CLOSED  Open violations, variances, ordinances, approv...
# ...        ...     ...                                                ...
# 28843  21-5579  CLOSED  Hello, I would like a copy of the report from ...
# 28844  21-5581  CLOSED  Requesting incident report and photos for San ...
# 28845  21-5584  CLOSED           request for call for service
#
# 2110020816
# 28846  21-5588  CLOSED         request for call for service
#
# E20050048015
# 28847  21-5614  CLOSED  To Whom It May Concern,
#
# We are the property o...
#
#                            date  \
# 0      December 7, 2015 via web
# 1      December 7, 2015 via web
# 2      December 7, 2015 via web
# 3      December 7, 2015 via web
# 4      December 7, 2015 via web
# ...                         ...
# 28843  October 28, 2021 via web
# 28844  October 28, 2021 via web
# 28845  October 28, 2021 via web
# 28846  October 28, 2021 via web
# 28847  October 29, 2021 via web
#
#                                                   depts  \
# 0                                      Code Enforcement
# 1      Department of Real Estate and Airport Management
# 2                                            City Clerk
# 3      Department of Real Estate and Airport Management
# 4                                      Code Enforcement
# ...                                                 ...
# 28843                                   Animal Services
# 28844                                   Animal Services
# 28845                                            Police
# 28846                                            Police
# 28847                     Public Records Administration
#
#                                                     docs                 poc  \
# 0      title,link
# 5040 ShorehamPlace building permits...    Ginger Rodriguez
# 1                                                            Jeffrey Wallace
# 2      title,link
# http://www.sandiego.gov/park-and-re...  Mailei Ross-Cerezo
# 3                                                            Jeffrey Wallace
# 4      title,link
# Site Plan - 11943 El Camino Real.pd...    Ginger Rodriguez
# ...                                                  ...                 ...
# 28843                                                         Lori Hernandez
# 28844                                                         Lori Hernandez
# 28845  title,link
# 2110020816_Redacted.pdf,https://san...      Lori Hernandez
# 28846  title,link
# E20050048015_Redacted.pdf,https://s...      Lori Hernandez
# 28847                                                         Angela Laurita
#
#                                                     msgs
# 0      title,item,time
# "Request Closed
# Public",02. Re...
# 1      title,item,time
# "Request Published
# Public",,"D...
# 2      title,item,time
# "Request Closed
# Public",Still ...
# 3      title,item,time
# "Request Closed
# Public",02. Re...
# 4      title,item,time
# "Request Closed
# Public",02. Re...
# ...                                                  ...
# 28843  title,item,time
# "Request Published
# Public",,"N...
# 28844  title,item,time
# "Request Published
# Public",,"N...
# 28845  title,item,time
# "Request Published
# Public",,"N...
# 28846  title,item,time
# "Request Published
# Public",,"N...
# 28847  title,item,time
# "Request Published
# Public",,"N...
#
# [28848 rows x 8 columns]

# %%
csv_to_df = lambda csv: pd.read_csv(StringIO(csv)) if csv else None
test_df['docs_df'] = test_df['docs'].apply(csv_to_df)
test_df['msgs_df'] = test_df['msgs'].apply(csv_to_df)
test_df.head()
# Out:
#         id  status                                               desc  \
# 0  15-1810  CLOSED  Notices of Violation/Notice to Comply, fire in...
# 1  15-1811  CLOSED       The October 2015 monthly report for SeaWorld
# 2  15-1812  CLOSED  Records related to the following BIDS:  Adams ...
# 3  15-1813  CLOSED  Historical lease payments made by SeaWorld to ...
# 4  15-1814  CLOSED  Open violations, variances, ordinances, approv...
#
#                        date                                             depts  \
# 0  December 7, 2015 via web                                  Code Enforcement
# 1  December 7, 2015 via web  Department of Real Estate and Airport Management
# 2  December 7, 2015 via web                                        City Clerk
# 3  December 7, 2015 via web  Department of Real Estate and Airport Management
# 4  December 7, 2015 via web                                  Code Enforcement
#
#                                                 docs                 poc  \
# 0  title,link
# 5040 ShorehamPlace building permits...    Ginger Rodriguez
# 1                                                        Jeffrey Wallace
# 2  title,link
# http://www.sandiego.gov/park-and-re...  Mailei Ross-Cerezo
# 3                                                        Jeffrey Wallace
# 4  title,link
# Site Plan - 11943 El Camino Real.pd...    Ginger Rodriguez
#
#                                                 msgs  \
# 0  title,item,time
# "Request Closed
# Public",02. Re...
# 1  title,item,time
# "Request Published
# Public",,"D...
# 2  title,item,time
# "Request Closed
# Public",Still ...
# 3  title,item,time
# "Request Closed
# Public",02. Re...
# 4  title,item,time
# "Request Closed
# Public",02. Re...
#
#                                              docs_df  \
# 0                                       title  \
# ...
# 1                                               None
# 2                                                ...
# 3                                               None
# 4                                    title  \
# 0  ...
#
#                                              msgs_df
# 0                             title              ...
# 1                             title              ...
# 2                             title  \
# 0         ...
# 3                             title              ...
# 4                              title             ...

# %% [markdown]
# Then, we fill the NA values in the individual `docs` and `msgs` DataFrames:

# %%
test_df['docs_df'] = test_df['docs_df'].apply(df_fillna)
test_df['msgs_df'] = test_df['msgs_df'].apply(df_fillna)
test_df.loc[4]['msgs_df']
# Out:
#                            title                                  item  \
# 0          Request Closed
# Public                          02. Released
# 1    Document(s) Released
# Public  Site Plan - 11943 El Camino Real.pdf
# 2        Request Reopened
# Public
# 3          Request Closed
# Public                          02. Released
# 4    Document(s) Released
# Public           15-1814 Fire Responsive.pdf
# 5        Request Reopened
# Public
# 6          Request Closed
# Public                          02. Released
# 7        Request Reopened
# Public
# 8          Request Closed
# Public                          02. Released
# 9          Request Closed
# Public                          02. Released
# 10   Document(s) Released
# Public  Site Plan - 11943 El Camino Real.pdf
# 11      Request Published
# Public
# 12         Request Opened
# Public              Request received via web
# 13  Department Assignment
# Public                      Code Enforcement
# 14      Request Published
# Public
#
#                                                  time
# 0      December 24, 2015, 10:34am by Ginger Rodriquez
# 1      December 24, 2015, 10:33am by Ginger Rodriquez
# 2      December 24, 2015, 10:32am by Ginger Rodriquez
# 3       December 24, 2015, 8:09am by Ginger Rodriquez
# 4       December 24, 2015, 8:09am by Ginger Rodriquez
# 5   December 24, 2015, 8:02am by Amanda Alvarado, ...
# 6       December 17, 2015, 4:00pm by Ginger Rodriquez
# 7       December 17, 2015, 3:56pm by Ginger Rodriquez
# 8       December 17, 2015, 3:54pm by Ginger Rodriquez
# 9       December 17, 2015, 3:52pm by Ginger Rodriquez
# 10      December 17, 2015, 3:51pm by Ginger Rodriquez
# 11  December 8, 2015, 9:20am by Lea Fields-Bernard...
# 12  December 7, 2015, 5:39pm by Lea Fields-Bernard...
# 13                           December 7, 2015, 5:39pm
# 14                           December 7, 2015, 5:39pm

# %% [markdown]
# Other EDA stuff:

# %%
test_df.head()

# %%
test_df.shape[0] # Number of requests scraped

# %%
test_df[test_df['desc'].str.contains('Read more')] # Check if the descriptions were properly scraped
# Out:
# Empty DataFrame
# Columns: [id, status, desc, date, depts, docs, poc, msgs, docs_df, msgs_df]
# Index: []

# %%
empty_desc = test_df.query('desc == ""')
empty_desc
# Out:
#         id  status desc                      date  \
# 227  16-88  CLOSED       January 20, 2016 via web
#
#                              depts docs                 poc  \
# 227  Public Records Administration       Lea Fields-Bernard
#
#                                                   msgs docs_df  \
# 227  title,item,time
# "Request Closed
# Public","Not a...    None
#
#                                                msgs_df
# 227                            title  \
# 0         R...

# %%
# Check for empty depts field
empty_depts = test_df.query('depts == ""')
empty_depts
# Out:
#             id  status                                               desc  \
# 32     15-1842  CLOSED  Most recent "Statement of Acccount-Unpaid Chec...
# 153      16-14  CLOSED  Accounting of uncashed checks/warrants, tax ov...
# 184      16-45  CLOSED  Payments made in the amount of $10,000 or more...
# 267     16-128  CLOSED                                 Unclaimed warrants
# 306     16-167  CLOSED                         List of outstanding checks
# ...        ...     ...                                                ...
# 12367   19-669  CLOSED  Can the City please provide me with a copy of ...
# 13494  19-1798  CLOSED  Please produce the following:
# Application for ...
# 13629  19-1933  CLOSED  Copies of any and all contracts,service agreem...
# 15886  19-4190  CLOSED  I am requesting contracts for SDCCU Stadium th...
# 21407  20-3607  CLOSED  Please provide me with the SDMC 27.0402 public...
#
#                             date depts  \
# 32     December 10, 2015 via web
# 153      January 5, 2016 via web
# 184     January 12, 2016 via web
# 267     January 26, 2016 via web
# 306     February 1, 2016 via web
# ...                          ...   ...
# 12367  February 12, 2019 via web
# 13494     April 25, 2019 via web
# 13629        May 6, 2019 via web
# 15886  September 4, 2019 via web
# 21407  August 19, 2020 via email
#
#                                                     docs               poc  \
# 32                                                             Elena Perez
# 153    title,link
# http://www.sandiego.gov/comptroller...        Doug Enger
# 184    title,link
# PRA CCPRA2016-0045 1-21-2016.xlsx,h...       Elena Perez
# 267                                                            Elena Perez
# 306    title,link
# Outstanding Checks 1-19-2016.htm,ht...       Elena Perez
# ...                                                  ...               ...
# 12367  title,link
# 8531950_44131.pdf,https://sandiego....    Lori Hernandez
# 13494  title,link
# 19-1798 Permit #13756.pdf,https://s...    Lori Hernandez
# 13629  title,link
# Urban Corps Staffing for 08-07-14.p...    Lori Hernandez
# 15886                                                       Lori Hernandez
# 21407  title,link
# https://onbase.sandiego.gov/OnBaseA...  Danielle Fawcett
#
#                                                     msgs  \
# 32     title,item,time
# "Request Closed
# Public",No res...
# 153    title,item,time
# "Request Closed   Hide
# Public"...
# 184    title,item,time
# "Request Closed
# Public","02. R...
# 267    title,item,time
# "Request Closed
# Public","02. R...
# 306    title,item,time
# "Request Closed
# Public","02. R...
# ...                                                  ...
# 12367  title,item,time
# "Request Published
# Public",,"F...
# 13494  title,item,time
# "Request Published
# Public",,"A...
# 13629  title,item,time
# "Request Published
# Public",,"J...
# 15886  title,item,time
# "Request Published
# Public",,"S...
# 21407  title,item,time
# "Request Published
# Public",,"A...
#
#                                                  docs_df  \
# 32                                                  None
# 153                                                  ...
# 184                                   title  \
# 0  PRA...
# 267                                                 None
# 306                                  title  \
# 0  Outs...
# ...                                                  ...
# 12367                 title                          ...
# 13494                                                ...
# 13629                                                ...
# 15886                                               None
# 21407                                                ...
#
#                                                  msgs_df
# 32                               title               ...
# 153                              title  \
# 0  Request ...
# 184                              title  \
# 0         R...
# 267                              title  \
# 0         R...
# 306                              title  \
# 0         R...
# ...                                                  ...
# 12367                            title  \
# 0      Requ...
# 13494                                      title  \
# 0...
# 13629                                     title  \
# 0 ...
# 15886                            title  \
# 0      Requ...
# 21407                                     title  \
# 0 ...
#
# [143 rows x 10 columns]

# %%
# Check for empty docs field
empty_docs = test_df[test_df['docs'].str.fullmatch('title,link\n')]
empty_docs
# Out:
#             id  status                                               desc  \
# 6659   17-3623  CLOSED  Dear Records Officer:
# I would like to request ...
# 7533    18-658  CLOSED  All emails sent by Council member Barbara Bry ...
# 9814   18-2940  CLOSED  August 3, 2018
#    City of San Diego, CA
# City A...
# 10883  18-4010  CLOSED  Please provide copies of PID, PAD, PCD, NUP, P...
# 10894  18-4021  CLOSED  October 22, 2018
#
# To whom it may concern:
#
# Und...
# ...        ...     ...                                                ...
# 28633  21-5230  CLOSED  Please provide any insurance information regar...
# 28660  21-5261  CLOSED  request for 2 call for service reports
#
# 211000...
# 28769  21-5392  CLOSED  request for 4 call for services
#
# 21100008435
# 2...
# 28770  21-5394  CLOSED  I'm looking for code enforcement information o...
# 28772  21-5396  CLOSED         19010013246 please provide incident report
#
#                             date                                  depts  \
# 6659    December 8, 2017 via web       Engineering and Capital Projects
# 7533   February 16, 2018 via web                City Council District 1
# 9814      August 3, 2018 via web       Engineering and Capital Projects
# 10883   October 25, 2018 via web                   Development Services
# 10894   October 25, 2018 via web  Police, Public Records Administration
# ...                          ...                                    ...
# 28633    October 6, 2021 via web                   Development Services
# 28660    October 7, 2021 via web                                 Police
# 28769   October 15, 2021 via web                                 Police
# 28770   October 16, 2021 via web                       Code Enforcement
# 28772   October 16, 2021 via web                                 Police
#
#               docs                poc  \
# 6659   title,link
#   Jacqueline Palmer
# 7533   title,link
#       Steven Hadley
# 9814   title,link
#    Ginger Rodriguez
# 10883  title,link
#    Ginger Rodriguez
# 10894  title,link
#      Angela Laurita
# ...            ...                ...
# 28633  title,link
#    Ginger Rodriguez
# 28660  title,link
#      Lori Hernandez
# 28769  title,link
#      Angela Laurita
# 28770  title,link
#    Ginger Rodriguez
# 28772  title,link
#      Angela Laurita
#
#                                                     msgs  \
# 6659   title,item,time
# "Request Published
# Public",,"D...
# 7533   title,item,time
# "Department Assignment
# Public"...
# 9814   title,item,time
# "Request Published
# Public",,"A...
# 10883  title,item,time
# "Request Published
# Public",,"N...
# 10894  title,item,time
# "Request Published
# Public",,"N...
# ...                                                  ...
# 28633  title,item,time
# "Request Published
# Public",,"O...
# 28660  title,item,time
# "Request Published
# Public",,"O...
# 28769  title,item,time
# "Request Published
# Public",,"O...
# 28770  title,item,time
# "Request Published
# Public",,"O...
# 28772  title,item,time
# "Request Published
# Public",,"O...
#
#                                                 docs_df  \
# 6659   Empty DataFrame
# Columns: [title, link]
# Index: []
# 7533   Empty DataFrame
# Columns: [title, link]
# Index: []
# 9814   Empty DataFrame
# Columns: [title, link]
# Index: []
# 10883  Empty DataFrame
# Columns: [title, link]
# Index: []
# 10894  Empty DataFrame
# Columns: [title, link]
# Index: []
# ...                                                 ...
# 28633  Empty DataFrame
# Columns: [title, link]
# Index: []
# 28660  Empty DataFrame
# Columns: [title, link]
# Index: []
# 28769  Empty DataFrame
# Columns: [title, link]
# Index: []
# 28770  Empty DataFrame
# Columns: [title, link]
# Index: []
# 28772  Empty DataFrame
# Columns: [title, link]
# Index: []
#
#                                                  msgs_df
# 6659                                      title  \
# 0 ...
# 7533                             title  \
# 0  Departme...
# 9814                                      title  \
# 0 ...
# 10883                                     title  \
# 0 ...
# 10894                            title  \
# 0      Requ...
# ...                                                  ...
# 28633                            title  \
# 0      Requ...
# 28660                            title  \
# 0      Requ...
# 28769                            title  \
# 0      Requ...
# 28770                            title  \
# 0      Requ...
# 28772                            title  \
# 0      Requ...
#
# [104 rows x 10 columns]

# %%
# Which requests had the longest message history? (Useful for finding worst-case scenarios for the scraper)
long_msgs = test_df['msgs_df'].apply(lambda df: df.shape[0] if df is not None else 0).sort_values(ascending=False)
long_msgs.head(10)
# Out:
# 3092    1117
# 2495     814
# 1721     313
# 676      174
# 2562     160
# 3109     153
# 6674     145
# 3971     142
# 6727     130
# 5895     126
# Name: msgs_df, dtype: int64

# %%
# Sort requests by message history length
requests_long_msg = test_df.loc[long_msgs.index]
requests_long_msg.head(20)
# Out:
#             id  status                                               desc  \
# 3092     17-22  CLOSED  I would like to review the photographs in File...
# 2495   16-2363  CLOSED    Pursuant to the California Public Records Ac...
# 1721   16-1588  CLOSED  The San Diego Police Department’s “Policies an...
# 676     16-541  CLOSED  This is a request for:
# 1. all inspection and e...
# 2562   16-2430  CLOSED  This is a request under the California Public ...
# 3109     17-39  CLOSED  Good afternoon,
# I'm requesting all appointment...
# 6674   17-3638  CLOSED   We are requesting that you produce all record...
# 3971    17-901  CLOSED  Re residential real property at 1867 Irving Av...
# 6727   17-3691  CLOSED  I am requesting copies of the following public...
# 5895   17-2858  CLOSED  Records related to the Linda Vista skatepark p...
# 129    15-1939  CLOSED  Formal RP proposal responses, Intergraph contr...
# 11961   19-263  CLOSED  For each unit of housing built, subsidized, or...
# 2119   16-1987  CLOSED  Any and all capital improvement invoices/repor...
# 3720    17-650  CLOSED  Please accept on behalf of Coastal Environment...
# 1859   16-1726  CLOSED  Please provide all documents related to the Ci...
# 14166  19-2470  CLOSED  This is a request under the California Public ...
# 2700   16-2600  CLOSED  Records related to settlement between the City...
# 19496  20-1682  CLOSED  Please provide the following public records:
# 1...
# 19196  20-1382  CLOSED  Hello,
# Please consider this message as a reque...
# 3050   16-2950  CLOSED  Records relating to proposed ordinance to amen...
#
#                               date  \
# 3092       January 4, 2017 via web
# 2495       October 7, 2016 via web
# 1721         July 29, 2016 via web
# 676         March 24, 2016 via web
# 2562      October 14, 2016 via web
# 3109       January 5, 2017 via web
# 6674    December 5, 2017 via email
# 3971        April 12, 2017 via web
# 6727   December 14, 2017 via email
# 5895      October 3, 2017 via mail
# 129      December 29, 2015 via web
# 11961     January 17, 2019 via web
# 2119       August 30, 2016 via web
# 3720        March 17, 2017 via web
# 1859       August 10, 2016 via web
# 14166         June 7, 2019 via web
# 2700      November 2, 2016 via web
# 19496       April 13, 2020 via web
# 19196       March 17, 2020 via web
# 3050     December 28, 2016 via web
#
#                                                    depts  \
# 3092                                    Code Enforcement
# 2495                       Public Records Administration
# 1721                       Public Records Administration
# 676                        Public Records Administration
# 2562                       Public Records Administration
# 3109                         City Council Administration
# 6674                                       City Attorney
# 3971              Code Enforcement, Development Services
# 6727                                           Personnel
# 5895   Equal Opportunity Contracting, Engineering and...
# 129                             Purchasing & Contracting
# 11961                        City Council Administration
# 2119                       Public Records Administration
# 3720                                      Transportation
# 1859                       Public Records Administration
# 14166                                      City Attorney
# 2700                                       City Attorney
# 19496  City Attorney, Development Services, Planning ...
# 19196     Risk Management, Public Records Administration
# 3050                                Development Services
#
#                                                     docs  \
# 3092   title,link
# P3090002.JPG,https://sandiego.nextr...
# 2495   title,link
# Various Emails (8).pdf,https://sand...
# 1721   title,link
# DP 809.pdf,https://sandiego.nextreq...
# 676    title,link
# IMG_4868.pdf,https://sandiego.nextr...
# 2562   title,link
# 6. Council Resolutions_R-310557 7-6...
# 3109   title,link
# 2016 Calendar MK.pdf,https://sandie...
# 6674
# 3971   title,link
# 030.JPG,https://sandiego.nextreques...
# 6727
# 5895   title,link
# Letter of Complaint - 3-D.pdf,https...
# 129    title,link
# (1) Section L - Software License Ag...
# 11961  title,link
# SDHC Affordable Housing Fund Fiscal...
# 2119   title,link
# PO4500038427 Hanan&Assoc Children's...
# 3720   title,link
# IMAG2787.jpg,https://sandiego.nextr...
# 1859   title,link
# Re_ short response to comment neede...
# 14166  title,link
# H166742 - As-Needed Orientation & M...
# 2700   title,link
# #10 TMY Farms 60165.pdf,https://san...
# 19496  title,link
# CED Responsivle IT email.pdf,https:...
# 19196  title,link
# FINAL Telecommuting 20-1382_REDACTE...
# 3050   title,link
# USEPA 2005 - List of Hazd Air Pollu...
#
#                           poc  \
# 3092         Ginger Rodriguez
# 2495       Lea Fields-Bernard
# 1721       Lea Fields-Bernard
# 676        Lea Fields-Bernard
# 2562       Lea Fields-Bernard
# 3109              Lori Witzel
# 6674            Nancy Shapiro
# 3971           Angela Laurita
# 6727           Yajaira Gharst
# 5895        Jacqueline Palmer
# 129    Stacy Roberts-Gilhooly
# 11961             Lori Witzel
# 2119       Lea Fields-Bernard
# 3720        Jacqueline Palmer
# 1859           Angela Laurita
# 14166        Danielle Fawcett
# 2700            Nancy Shapiro
# 19496        Danielle Fawcett
# 19196          Angela Laurita
# 3050           Angela Laurita
#
#                                                     msgs  \
# 3092   title,item,time
# "Request Published
# Public",,"J...
# 2495   title,item,time
# "Request Published
# Public",,"J...
# 1721   title,item,time
# "Request Published
# Public",,"S...
# 676    title,item,time
# "Request Published
# Public",,"M...
# 2562   title,item,time
# "Request Published
# Public",,"N...
# 3109   title,item,time
# "Document(s) Released   Detail...
# 6674   title,item,time
# "Request Published
# Public",,"D...
# 3971   title,item,time
# "Request Closed
# Public","Reque...
# 6727   title,item,time
# "Request Published
# Public",,"D...
# 5895   title,item,time
# "Request Published
# Public",,"D...
# 129    title,item,time
# "Request Closed
# Public","02. R...
# 11961  title,item,time
# "Request Published
# Public",,"S...
# 2119   title,item,time
# "Request Published
# Public",,"O...
# 3720   title,item,time
# "Request Published
# Public",,"A...
# 1859   title,item,time
# "Request Published
# Public",,"D...
# 14166  title,item,time
# "Request Published
# Public",,"A...
# 2700   title,item,time
# "Request Closed   Hide
# Public"...
# 19496  title,item,time
# "Request Published
# Public",,"N...
# 19196  title,item,time
# "Request Published
# Public",,"S...
# 3050   title,item,time
# "Request Closed   Hide
# Public"...
#
#                                                  docs_df  \
# 3092                                title  \
# 0       ...
# 2495                                                 ...
# 1721                                                 ...
# 676                                               tit...
# 2562                                                 ...
# 3109                                                 ...
# 6674                                                None
# 3971                                                 ...
# 6727                                                None
# 5895                                                 ...
# 129                                                  ...
# 11961                                                ...
# 2119                                                 ...
# 3720                                                 ...
# 1859                                                 ...
# 14166                                                ...
# 2700                           title  \
# 0     #10 TMY...
# 19496                                                ...
# 19196                                                ...
# 3050                                                 ...
#
#                                                  msgs_df
# 3092                                title  \
# 0       ...
# 2495                               title  \
# 0        ...
# 1721                               title  \
# 0        ...
# 676                                title  \
# 0        ...
# 2562                               title  \
# 0        ...
# 3109                                        title  \
# ...
# 6674                                           title ...
# 3971                               title  \
# 0        ...
# 6727                                           title ...
# 5895                               title  \
# 0        ...
# 129                                title  \
# 0        ...
# 11961                                       title  \
# ...
# 2119                               title  \
# 0        ...
# 3720                              title  \
# 0       Re...
# 1859                              title  \
# 0       Re...
# 14166                                      title  \
# 0...
# 2700                              title  \
# 0   Reques...
# 19496                                         title  ...
# 19196                                       title  \
# ...
# 3050                              title  \
# 0   Reques...

# %%
# Query for info about a specific request
request_id = '"17-22"'
test_df.query('id == ' + request_id).iloc[0]['msgs_df']
# Out:
#                              title  \
# 0         Request Published
# Public
# 1            Request Closed
# Public
# 2      Document(s) Released
# Public
# 3      Document(s) Released
# Public
# 4      Document(s) Released
# Public
# ...                            ...
# 1112   Document(s) Released
# Public
# 1113   Document(s) Released
# Public
# 1114   Document(s) Released
# Public
# 1115  Department Assignment
# Public
# 1116         Request Opened
# Public
#
#                                                    item  \
# 0
# 1     02. Released
# All responsive documents have bee...
# 2                                   20160315_131321.jpg
# 3                                   20160315_131307.jpg
# 4                                   20160315_131230.jpg
# ...                                                 ...
# 1112                                20160307_155141.jpg
# 1113                                20160307_155139.jpg
# 1114                     7411 Hillside Drive Photos.pdf
# 1115                                   Code Enforcement
# 1116                           Request received via web
#
#                                                    time
# 0                              January 16, 2017, 4:10pm
# 1          January 13, 2017, 4:06pm by Ginger Rodriquez
# 2          January 13, 2017, 4:00pm by Ginger Rodriquez
# 3          January 13, 2017, 4:00pm by Ginger Rodriquez
# 4          January 13, 2017, 4:00pm by Ginger Rodriquez
# ...                                                 ...
# 1112       January 13, 2017, 3:54pm by Ginger Rodriquez
# 1113       January 13, 2017, 3:54pm by Ginger Rodriquez
# 1114       January 13, 2017, 3:54pm by Ginger Rodriquez
# 1115  January 6, 2017, 3:23pm by Lea Fields-Bernard,...
# 1116                           January 4, 2017, 10:08am
#
# [1117 rows x 3 columns]

# %%
# Find request descriptions with the given substring, case insensitive
desc = 'Padres'
test_df[test_df['desc'].str.contains(desc, case=False)]
# Out:
#             id  status                                               desc  \
# 487     16-348  CLOSED  Joint ballpark ownership expenses, incremental...
# 583     16-444  CLOSED  Amount of times the SDFD and EMS have been cal...
# 584     16-445  CLOSED  Padres projected 2016 capital expenditures bas...
# 622     16-486  CLOSED  I am requesting an opportunity to inspect or o...
# 648     16-513  CLOSED  -information about any time the San Diego Depa...
# 1354   16-1221  CLOSED  Any emails exchanged between the city and the ...
# 2400   16-2268  CLOSED  All emails (dated between January 1, 2012 and ...
# 2940   16-2840  CLOSED  I am requesting as copy of the city's contract...
# 3268    17-198  CLOSED  All e-mails between Miguel Duran, city ballpar...
# 5564   17-2495  CLOSED  Requesting copies of public records (that are ...
# 6354   17-3318  CLOSED  Hello sir or madam:
# Pursuant to my rights unde...
# 6631   17-3595  CLOSED  Any and all records which reveal the deploymen...
# 8003   18-1129  CLOSED  To Whom It May Concern:
# I am writing today to ...
# 8341   18-1467  CLOSED  To Whom It May Concern:
# I am writing today to ...
# 11510  18-4638  CLOSED  MEMORANDUM OF UNDERSTANDING
# BETWEEN
# THE CITY O...
# 11611  18-4739  CLOSED   I WOULD LIKE TO REQUEST AN INSPECTION OF OF T...
# 11764    19-66  CLOSED  Hello Mara Elliott
# San Diego City Attorney,
# I ...
# 11820   19-122  CLOSED  Requesting copies of all public records (that ...
# 12019   19-321  CLOSED  Requesting the FY16, FY17, and FY18 Padres Cap...
# 12770  19-1073  CLOSED  My Client: Jenny Michael (FL 1776)
# Accident Da...
# 12904  19-1207  CLOSED  Bremer, Whyte, Brown & O’Meara, LLP represents...
# 13672  19-1976  CLOSED  IN MATTER RE;
# OFFICIAL RECORDS REQUEST FOR DOC...
# 15429  19-3733  CLOSED  DEAR CITY OF SAN DIEGO ATTORNEY.
#
# I WOULD LIKE...
# 16393  19-4698  CLOSED  HARD COPY OF REQUEST TO FOLLOW BY OVERNIGHT DE...
# 16661  19-4966  CLOSED  This letter constitutes a request under the Pu...
# 17199  19-5505  CLOSED  HELLO SAN DIEGO CITY ATTORNEY
# MARA ELLIOTT,
# AS...
# 17328  19-5634  CLOSED  Copy of the City's current lease with the Padr...
# 19923  20-2110  CLOSED  This will constitute a request under the Calif...
# 20548  20-2739  CLOSED                          June 3, 2020
#
# Office o...
# 21878  20-4083  CLOSED  I am requesting data on the SDPD officers and ...
# 22409  20-4619  CLOSED  This is a request made pursuant to the Public ...
# 24384   21-797  CLOSED  Requesting any publicly available records on t...
# 28493  21-5067  CLOSED  Pleases provide the financial analysis ("model...
#
#                               date  \
# 487      February 29, 2016 via web
# 583         March 11, 2016 via web
# 584         March 11, 2016 via web
# 622         March 16, 2016 via web
# 648         March 21, 2016 via web
# 1354         June 16, 2016 via web
# 2400    September 27, 2016 via web
# 2940      December 7, 2016 via web
# 3268      January 26, 2017 via web
# 5564    September 13, 2017 via web
# 6354     November 10, 2017 via web
# 6631      December 5, 2017 via web
# 8003        March 27, 2018 via web
# 8341        April 19, 2018 via web
# 11510    December 11, 2018 via web
# 11611    December 18, 2018 via web
# 11764      January 6, 2019 via web
# 11820      January 9, 2019 via web
# 12019     January 22, 2019 via web
# 12770     March 11, 2019 via email
# 12904       March 20, 2019 via web
# 13672         May 7, 2019 via mail
# 15429      August 7, 2019 via mail
# 16393      October 3, 2019 via web
# 16661     October 16, 2019 via web
# 17199    November 14, 2019 via web
# 17328  November 21, 2019 via email
# 19923       May 14, 2020 via email
# 20548        June 29, 2020 via web
# 21878   September 14, 2020 via web
# 22409   October 15, 2020 via email
# 24384    February 16, 2021 via web
# 28493   September 26, 2021 via web
#
#                                                    depts  \
# 487     Department of Real Estate and Airport Management
# 583                        Public Records Administration
# 584     Department of Real Estate and Airport Management
# 622     Department of Real Estate and Airport Management
# 648                        Public Records Administration
# 1354                       Public Records Administration
# 2400                             City Council District 7
# 2940                       Public Records Administration
# 3268
# 5564
# 6354   Mayor, Public Records Administration , Deputy ...
# 6631                                              Police
# 8003                         City Council Administration
# 8341                         City Council Administration
# 11510                              Department of Finance
# 11611  Department of Real Estate and Airport Manageme...
# 11764                               Economic Development
# 11820   Department of Real Estate and Airport Management
# 12019
# 12770   Department of Real Estate and Airport Management
# 12904                                             Police
# 13672                                      City Attorney
# 15429   Department of Real Estate and Airport Management
# 16393   Department of Real Estate and Airport Management
# 16661  Deputy Chief Operating Officer - Internal Oper...
# 17199                                    Debt Management
# 17328                      Public Records Administration
# 19923   Department of Real Estate and Airport Management
# 20548   Department of Real Estate and Airport Management
# 21878  Fire-Rescue, Police, Public Records Administra...
# 22409                               Economic Development
# 24384                                             Police
# 28493                                              Mayor
#
#                                                     docs                 poc  \
# 487    title,link
# 2015 JBOE Reconciliation.pdf,https:...     Jeffrey Wallace
# 583    title,link
# PetCo Park 911 EMS Response for Fou...  Lea Fields-Bernard
# 584    title,link
# CapEx Letter 2015-2016 executed.pdf...     Jeffrey Wallace
# 622    title,link
# 2013 Petco Park Non Baseball Events...     Jeffrey Wallace
# 648                                                       Lea Fields-Bernard
# 1354                                                      Lea Fields-Bernard
# 2400                                                          Barrett Tetlow
# 2940   title,link
# Ballpark Debt Service Schedule.pdf,...  Lea Fields-Bernard
# 3268   title,link
# Miguel Durans Petco Ballpark Emails...      Angela Laurita
# 5564   title,link
# FY 2016 Capital Expenditures - Fina...      Angela Laurita
# 6354   title,link
# 17-3318_Bridge Shelters_MayorCOO Ba...      Angela Laurita
# 6631                                                          Angela Laurita
# 8003                                                             Lori Witzel
# 8341                                                             Lori Witzel
# 11510  title,link
# Ballpark MOU 2nd Imp Agr.pdf,https:...      Angela Laurita
# 11611  title,link
# Security Agreement.pdf,https://sand...      Angela Laurita
# 11764                                                         Lori Hernandez
# 11820  title,link
# 03-02-2018.pdf,https://sandiego.nex...      Lori Hernandez
# 12019  title,link
# CapEx Reconciliation 2017(PRA19-321...      Lori Hernandez
# 12770  title,link
# Padres - City of San Diego 75M.PDF,...      Lori Hernandez
# 12904  title,link
# 485577 Traffic Control Permit.pdf,h...      Angela Laurita
# 13672  title,link
# Petco East Village Square CCRs.pdf,...       Nancy Shapiro
# 15429  title,link
# Ballpark 2002 Official Statement.pd...      Lori Hernandez
# 16393  title,link
# KAABOO Music Festival_Responsive Do...      Lori Hernandez
# 16661  title,link
# KAABOO Music Festival_Responsive Do...      Angela Laurita
# 17199  title,link
# Ballpark 2002 Official Statement.pd...      Angela Laurita
# 17328  title,link
# Tailgate Lot Lease.pdf,https://sand...      Angela Laurita
# 19923  title,link
# PRA_20-2110_Stump-_Ottilie_PRA_emai...      Lori Hernandez
# 20548  title,link
# R.E.A.D. Email w. Padres_City Suite...      Lori Hernandez
# 21878                                                         Angela Laurita
# 22409                                                         Lori Hernandez
# 24384  title,link
# PRA 21-797 Event History E201000189...      Angela Laurita
# 28493  title,link
# https://onbase.sandiego.gov/OnBaseA...      Angela Laurita
#
#                                                     msgs  \
# 487    title,item,time
# "Request Closed
# Public","02. R...
# 583    title,item,time
# "Request Closed
# Public","02. R...
# 584    title,item,time
# "Request Closed
# Public","02. R...
# 622    title,item,time
# "Request Published
# Public",,"M...
# 648    title,item,time
# "Request Published
# Public",,"M...
# 1354   title,item,time
# "Request Published
# Public",,"J...
# 2400   title,item,time
# "Request Published
# Public",,"O...
# 2940   title,item,time
# "Request Published
# Public",,"D...
# 3268   title,item,time
# "Request Published
# Public",,"F...
# 5564   title,item,time
# "Request Published
# Public",,"S...
# 6354   title,item,time
# "Request Published
# Public",,"M...
# 6631   title,item,time
# "Request Published
# Public",,"D...
# 8003   title,item,time
# "Request Published
# Public",,"A...
# 8341   title,item,time
# "Request Published
# Public",,"M...
# 11510  title,item,time
# "Request Published
# Public",,"J...
# 11611  title,item,time
# "Request Published
# Public",,"J...
# 11764  title,item,time
# "Request Published
# Public",,"J...
# 11820  title,item,time
# "Request Published
# Public",,"J...
# 12019  title,item,time
# "Request Published
# Public",,"F...
# 12770  title,item,time
# "Request Published
# Public",,"M...
# 12904  title,item,time
# "Request Published
# Public",,"J...
# 13672  title,item,time
# "Request Published
# Public",,"J...
# 15429  title,item,time
# "Request Published
# Public",,"A...
# 16393  title,item,time
# "Request Published
# Public",,"O...
# 16661  title,item,time
# "Request Published
# Public",,"D...
# 17199  title,item,time
# "Request Published
# Public",,"N...
# 17328  title,item,time
# "Request Published
# Public",,"N...
# 19923  title,item,time
# "Request Published
# Public",,"A...
# 20548  title,item,time
# "Request Published
# Public",,"S...
# 21878  title,item,time
# "Request Published
# Public",,"S...
# 22409  title,item,time
# "Request Published
# Public",,"O...
# 24384  title,item,time
# "Request Published
# Public",,"F...
# 28493  title,item,time
# "Request Published
# Public",,"O...
#
#                                                  docs_df  \
# 487                                                  ...
# 583                                                  ...
# 584                                     title  \
# 0  C...
# 622                                                  ...
# 648                                                 None
# 1354                                                None
# 2400                                                None
# 2940                                                 ...
# 3268                                                 ...
# 5564                                                 ...
# 6354                                              tit...
# 6631                                                None
# 8003                                                None
# 8341                                                None
# 11510                                   title  \
# 0   ...
# 11611                      title                     ...
# 11764                                               None
# 11820                               title  \
# 0       ...
# 12019                                                ...
# 12770                                  title  \
# 0  Pa...
# 12904                                                ...
# 13672                                                ...
# 15429                                    title  \
# 0  ...
# 16393                                        title  \...
# 16661                                                ...
# 17199                                    title  \
# 0  ...
# 17328                      title                     ...
# 19923                                                ...
# 20548                                                ...
# 21878                                               None
# 22409                                               None
# 24384                                                ...
# 28493                                                ...
#
#                                                  msgs_df
# 487                              title  \
# 0         R...
# 583                              title  \
# 0         R...
# 584                              title  \
# 0         R...
# 622                              title  \
# 0      Requ...
# 648                              title  \
# 0      Requ...
# 1354                             title  \
# 0      Requ...
# 2400                             title  \
# 0      Requ...
# 2940                             title  \
# 0      Requ...
# 3268                             title  \
# 0      Requ...
# 5564                                      title  \
# 0 ...
# 6354                             title  \
# 0      Requ...
# 6631                             title  \
# 0      Requ...
# 8003                             title  \
# 0      Requ...
# 8341                             title  \
# 0      Requ...
# 11510                             title  \
# 0       Re...
# 11611                            title  \
# 0      Requ...
# 11764                            title  \
# 0      Requ...
# 11820                                     title  \
# 0 ...
# 12019                            title  \
# 0      Requ...
# 12770                            title  \
# 0      Requ...
# 12904                                      title  \
# 0...
# 13672                                     title  \
# 0 ...
# 15429                            title  \
# 0      Requ...
# 16393                            title  \
# 0      Requ...
# 16661                            title  \
# 0      Requ...
# 17199                             title  \
# 0       Re...
# 17328                            title  \
# 0      Requ...
# 19923                                         title  ...
# 20548                             title  \
# 0       Re...
# 21878                            title  \
# 0      Requ...
# 22409                            title  \
# 0      Requ...
# 24384                            title  \
# 0      Requ...
# 28493                                     title  \
# 0 ...

# %%
# Find requests whose department(s) contain the given substring, case insensitive
dept = 'Police'
test_df[test_df['depts'].str.contains(dept, case=False)]
# Out:
#             id  status                                               desc  \
# 7      15-1817  CLOSED  File materials related to:
# P12010041171
# P12050...
# 49     15-1859  CLOSED  All records related to the demographic study c...
# 65     15-1875  CLOSED  Reports related to incident of 11/11/2015 wher...
# 81     15-1891  CLOSED  Communications by the City of San Diego regard...
# 121    15-1931  CLOSED  Vehicle Stop Data for period September 1, 2015...
# ...        ...     ...                                                ...
# 28838  21-5544  CLOSED  Dan you tell me when San Diego Police Officer ...
# 28839  21-5550  CLOSED  I request any police reports involving inciden...
# 28840  21-5552  CLOSED  The request is for the time of the towing call...
# 28845  21-5584  CLOSED           request for call for service
#
# 2110020816
# 28846  21-5588  CLOSED         request for call for service
#
# E20050048015
#
#                             date   depts  \
# 7       December 7, 2015 via web  Police
# 49     December 11, 2015 via web  Police
# 65     December 15, 2015 via web  Police
# 81     December 17, 2015 via web  Police
# 121    December 28, 2015 via web  Police
# ...                          ...     ...
# 28838   October 26, 2021 via web  Police
# 28839   October 27, 2021 via web  Police
# 28840   October 27, 2021 via web  Police
# 28845   October 28, 2021 via web  Police
# 28846   October 28, 2021 via web  Police
#
#                                                     docs                 poc  \
# 7                                                         Humberto Hernandez
# 49                                                        Humberto Hernandez
# 65                                                        Humberto Hernandez
# 81                                                        Humberto Hernandez
# 121                                                       Humberto Hernandez
# ...                                                  ...                 ...
# 28838                                                         Angela Laurita
# 28839                                                         Angela Laurita
# 28840                                                         Angela Laurita
# 28845  title,link
# 2110020816_Redacted.pdf,https://san...      Lori Hernandez
# 28846  title,link
# E20050048015_Redacted.pdf,https://s...      Lori Hernandez
#
#                                                     msgs  \
# 7      title,item,time
# "Request Closed
# Public",02c. R...
# 49     title,item,time
# "Request Closed   Hide
# Public"...
# 65     title,item,time
# "Request Closed
# Public","02. R...
# 81     title,item,time
# "Request Closed
# Public",Still ...
# 121    title,item,time
# "Request Closed
# Public",Still ...
# ...                                                  ...
# 28838  title,item,time
# "Request Published
# Public",,"N...
# 28839  title,item,time
# "Request Published
# Public",,"O...
# 28840  title,item,time
# "Request Published
# Public",,"O...
# 28845  title,item,time
# "Request Published
# Public",,"N...
# 28846  title,item,time
# "Request Published
# Public",,"N...
#
#                                                  docs_df  \
# 7                                                   None
# 49                                                  None
# 65                                                  None
# 81                                                  None
# 121                                                 None
# ...                                                  ...
# 28838                                               None
# 28839                                               None
# 28840                                               None
# 28845                       title                    ...
# 28846                         title  \
# 0  E2005004801...
#
#                                                  msgs_df
# 7                                title               ...
# 49                               title  \
# 0  Request ...
# 65                               title  \
# 0         R...
# 81                               title               ...
# 121                              title  \
# 0         R...
# ...                                                  ...
# 28838                            title  \
# 0      Requ...
# 28839                            title  \
# 0      Requ...
# 28840                            title  \
# 0      Requ...
# 28845                            title  \
# 0      Requ...
# 28846                            title  \
# 0      Requ...
#
# [6905 rows x 10 columns]

# %%
# Convert empty dataframes from docs_df into None
remove_empty = lambda df: None if ((df is None) or (type(df) == str and not df) or df.empty) else df
test_df['docs_df'] = test_df['docs_df'].apply(remove_empty)
test_df[test_df['docs'].str.fullmatch('title,link\n')]
# Out:
#             id  status                                               desc  \
# 6659   17-3623  CLOSED  Dear Records Officer:
# I would like to request ...
# 7533    18-658  CLOSED  All emails sent by Council member Barbara Bry ...
# 9814   18-2940  CLOSED  August 3, 2018
#    City of San Diego, CA
# City A...
# 10883  18-4010  CLOSED  Please provide copies of PID, PAD, PCD, NUP, P...
# 10894  18-4021  CLOSED  October 22, 2018
#
# To whom it may concern:
#
# Und...
# ...        ...     ...                                                ...
# 28633  21-5230  CLOSED  Please provide any insurance information regar...
# 28660  21-5261  CLOSED  request for 2 call for service reports
#
# 211000...
# 28769  21-5392  CLOSED  request for 4 call for services
#
# 21100008435
# 2...
# 28770  21-5394  CLOSED  I'm looking for code enforcement information o...
# 28772  21-5396  CLOSED         19010013246 please provide incident report
#
#                             date                                  depts  \
# 6659    December 8, 2017 via web       Engineering and Capital Projects
# 7533   February 16, 2018 via web                City Council District 1
# 9814      August 3, 2018 via web       Engineering and Capital Projects
# 10883   October 25, 2018 via web                   Development Services
# 10894   October 25, 2018 via web  Police, Public Records Administration
# ...                          ...                                    ...
# 28633    October 6, 2021 via web                   Development Services
# 28660    October 7, 2021 via web                                 Police
# 28769   October 15, 2021 via web                                 Police
# 28770   October 16, 2021 via web                       Code Enforcement
# 28772   October 16, 2021 via web                                 Police
#
#               docs                poc  \
# 6659   title,link
#   Jacqueline Palmer
# 7533   title,link
#       Steven Hadley
# 9814   title,link
#    Ginger Rodriguez
# 10883  title,link
#    Ginger Rodriguez
# 10894  title,link
#      Angela Laurita
# ...            ...                ...
# 28633  title,link
#    Ginger Rodriguez
# 28660  title,link
#      Lori Hernandez
# 28769  title,link
#      Angela Laurita
# 28770  title,link
#    Ginger Rodriguez
# 28772  title,link
#      Angela Laurita
#
#                                                     msgs docs_df  \
# 6659   title,item,time
# "Request Published
# Public",,"D...    None
# 7533   title,item,time
# "Department Assignment
# Public"...    None
# 9814   title,item,time
# "Request Published
# Public",,"A...    None
# 10883  title,item,time
# "Request Published
# Public",,"N...    None
# 10894  title,item,time
# "Request Published
# Public",,"N...    None
# ...                                                  ...     ...
# 28633  title,item,time
# "Request Published
# Public",,"O...    None
# 28660  title,item,time
# "Request Published
# Public",,"O...    None
# 28769  title,item,time
# "Request Published
# Public",,"O...    None
# 28770  title,item,time
# "Request Published
# Public",,"O...    None
# 28772  title,item,time
# "Request Published
# Public",,"O...    None
#
#                                                  msgs_df
# 6659                                      title  \
# 0 ...
# 7533                             title  \
# 0  Departme...
# 9814                                      title  \
# 0 ...
# 10883                                     title  \
# 0 ...
# 10894                            title  \
# 0      Requ...
# ...                                                  ...
# 28633                            title  \
# 0      Requ...
# 28660                            title  \
# 0      Requ...
# 28769                            title  \
# 0      Requ...
# 28770                            title  \
# 0      Requ...
# 28772                            title  \
# 0      Requ...
#
# [104 rows x 10 columns]

# %%
# Split the date and request method from the date column
dates = test_df['date'].to_numpy()
test_df = test_df.join(
        pd.DataFrame(list(map(lambda x: x.split(' via '), dates)))
    ).drop(
        columns='date'
    ).rename(
        columns={0: 'date', 1: 'via'}
    ).convert_dtypes()
test_df.head()
# Out:
#         id  status                                               desc  \
# 0  15-1810  CLOSED  Notices of Violation/Notice to Comply, fire in...
# 1  15-1811  CLOSED       The October 2015 monthly report for SeaWorld
# 2  15-1812  CLOSED  Records related to the following BIDS:  Adams ...
# 3  15-1813  CLOSED  Historical lease payments made by SeaWorld to ...
# 4  15-1814  CLOSED  Open violations, variances, ordinances, approv...
#
#                                               depts  \
# 0                                  Code Enforcement
# 1  Department of Real Estate and Airport Management
# 2                                        City Clerk
# 3  Department of Real Estate and Airport Management
# 4                                  Code Enforcement
#
#                                                 docs                 poc  \
# 0  title,link
# 5040 ShorehamPlace building permits...    Ginger Rodriguez
# 1                                                        Jeffrey Wallace
# 2  title,link
# http://www.sandiego.gov/park-and-re...  Mailei Ross-Cerezo
# 3                                                        Jeffrey Wallace
# 4  title,link
# Site Plan - 11943 El Camino Real.pd...    Ginger Rodriguez
#
#                                                 msgs  \
# 0  title,item,time
# "Request Closed
# Public",02. Re...
# 1  title,item,time
# "Request Published
# Public",,"D...
# 2  title,item,time
# "Request Closed
# Public",Still ...
# 3  title,item,time
# "Request Closed
# Public",02. Re...
# 4  title,item,time
# "Request Closed
# Public",02. Re...
#
#                                              docs_df  \
# 0                                       title  \
# ...
# 1                                               None
# 2                                                ...
# 3                                               None
# 4                                    title  \
# 0  ...
#
#                                              msgs_df              date  via
# 0                            title               ...  December 7, 2015  web
# 1                            title               ...  December 7, 2015  web
# 2                            title  \
# 0         R...  December 7, 2015  web
# 3                            title               ...  December 7, 2015  web
# 4                             title              ...  December 7, 2015  web

# %%
# Split the time and author from the time quote on each message
def split_time_author(msgs):
    if msgs is None:
        return None
    time_quotes = msgs['time'].to_numpy()
    time_author = pd.DataFrame(list(map(lambda x: x.split(' by '), time_quotes)))
    # dataset.str.split(expand=True)
    return df_fillna(msgs.join(
            time_author
        ).drop(
            columns='time'
        ).rename(
            columns={0: 'time', 1: 'by'}
        ))

test_df['msgs_df'] = test_df['msgs_df'].apply(split_time_author)
test_df.loc[4]['msgs_df']
# Out:
#                            title                                  item  \
# 0          Request Closed
# Public                          02. Released
# 1    Document(s) Released
# Public  Site Plan - 11943 El Camino Real.pdf
# 2        Request Reopened
# Public
# 3          Request Closed
# Public                          02. Released
# 4    Document(s) Released
# Public           15-1814 Fire Responsive.pdf
# 5        Request Reopened
# Public
# 6          Request Closed
# Public                          02. Released
# 7        Request Reopened
# Public
# 8          Request Closed
# Public                          02. Released
# 9          Request Closed
# Public                          02. Released
# 10   Document(s) Released
# Public  Site Plan - 11943 El Camino Real.pdf
# 11      Request Published
# Public
# 12         Request Opened
# Public              Request received via web
# 13  Department Assignment
# Public                      Code Enforcement
# 14      Request Published
# Public
#
#                           time  \
# 0   December 24, 2015, 10:34am
# 1   December 24, 2015, 10:33am
# 2   December 24, 2015, 10:32am
# 3    December 24, 2015, 8:09am
# 4    December 24, 2015, 8:09am
# 5    December 24, 2015, 8:02am
# 6    December 17, 2015, 4:00pm
# 7    December 17, 2015, 3:56pm
# 8    December 17, 2015, 3:54pm
# 9    December 17, 2015, 3:52pm
# 10   December 17, 2015, 3:51pm
# 11    December 8, 2015, 9:20am
# 12    December 7, 2015, 5:39pm
# 13    December 7, 2015, 5:39pm
# 14    December 7, 2015, 5:39pm
#
#                                                    by
# 0                                    Ginger Rodriquez
# 1                                    Ginger Rodriquez
# 2                                    Ginger Rodriquez
# 3                                    Ginger Rodriquez
# 4                                    Ginger Rodriquez
# 5                       Amanda Alvarado, Senior Clerk
# 6                                    Ginger Rodriquez
# 7                                    Ginger Rodriquez
# 8                                    Ginger Rodriquez
# 9                                    Ginger Rodriquez
# 10                                   Ginger Rodriquez
# 11  Lea Fields-Bernard, Public Records Administrat...
# 12  Lea Fields-Bernard, Public Records Administrat...
# 13
# 14

# %%
# Convert columns with time strings into DateTime
def convert_time_to_dt(df, col='time'):
    return df.assign(**{col + '_dt': pd.to_datetime(df[col])})

test_df['msgs_df'] = test_df['msgs_df'].apply(convert_time_to_dt)
test_df.loc[4]['msgs_df']
# Out:
#                            title                                  item  \
# 0          Request Closed
# Public                          02. Released
# 1    Document(s) Released
# Public  Site Plan - 11943 El Camino Real.pdf
# 2        Request Reopened
# Public
# 3          Request Closed
# Public                          02. Released
# 4    Document(s) Released
# Public           15-1814 Fire Responsive.pdf
# 5        Request Reopened
# Public
# 6          Request Closed
# Public                          02. Released
# 7        Request Reopened
# Public
# 8          Request Closed
# Public                          02. Released
# 9          Request Closed
# Public                          02. Released
# 10   Document(s) Released
# Public  Site Plan - 11943 El Camino Real.pdf
# 11      Request Published
# Public
# 12         Request Opened
# Public              Request received via web
# 13  Department Assignment
# Public                      Code Enforcement
# 14      Request Published
# Public
#
#                           time  \
# 0   December 24, 2015, 10:34am
# 1   December 24, 2015, 10:33am
# 2   December 24, 2015, 10:32am
# 3    December 24, 2015, 8:09am
# 4    December 24, 2015, 8:09am
# 5    December 24, 2015, 8:02am
# 6    December 17, 2015, 4:00pm
# 7    December 17, 2015, 3:56pm
# 8    December 17, 2015, 3:54pm
# 9    December 17, 2015, 3:52pm
# 10   December 17, 2015, 3:51pm
# 11    December 8, 2015, 9:20am
# 12    December 7, 2015, 5:39pm
# 13    December 7, 2015, 5:39pm
# 14    December 7, 2015, 5:39pm
#
#                                                    by             time_dt
# 0                                    Ginger Rodriquez 2015-12-24 10:34:00
# 1                                    Ginger Rodriquez 2015-12-24 10:33:00
# 2                                    Ginger Rodriquez 2015-12-24 10:32:00
# 3                                    Ginger Rodriquez 2015-12-24 08:09:00
# 4                                    Ginger Rodriquez 2015-12-24 08:09:00
# 5                       Amanda Alvarado, Senior Clerk 2015-12-24 08:02:00
# 6                                    Ginger Rodriquez 2015-12-17 16:00:00
# 7                                    Ginger Rodriquez 2015-12-17 15:56:00
# 8                                    Ginger Rodriquez 2015-12-17 15:54:00
# 9                                    Ginger Rodriquez 2015-12-17 15:52:00
# 10                                   Ginger Rodriquez 2015-12-17 15:51:00
# 11  Lea Fields-Bernard, Public Records Administrat... 2015-12-08 09:20:00
# 12  Lea Fields-Bernard, Public Records Administrat... 2015-12-07 17:39:00
# 13                                                    2015-12-07 17:39:00
# 14                                                    2015-12-07 17:39:00

# %%
# Splitting departments for easier pivoting
depts = test_df['depts'].to_numpy() # depts column
test_df_depts = test_df.join(pd.DataFrame(list(map(lambda x: x.split(', '), depts)))) # Split departments into separate columns
test_df_depts = test_df_depts.melt( # Melt on the individual departments
        id_vars=test_df.columns
    )[lambda df: df['value'].apply(lambda x: x is not None)].drop( # Get rid of None values
        columns='variable'
    ).rename( # Drop the variable column, rename the value column, and reset indices
        columns={'value': 'dept'}
    ).reset_index().drop(
        columns='index'
    )
test_df_depts
# Out:
#             id  status                                               desc  \
# 0      15-1810  CLOSED  Notices of Violation/Notice to Comply, fire in...
# 1      15-1811  CLOSED       The October 2015 monthly report for SeaWorld
# 2      15-1812  CLOSED  Records related to the following BIDS:  Adams ...
# 3      15-1813  CLOSED  Historical lease payments made by SeaWorld to ...
# 4      15-1814  CLOSED  Open violations, variances, ordinances, approv...
# ...        ...     ...                                                ...
# 32430  20-4254  CLOSED  All emails with the attachment of the prelimin...
# 32431  20-4254  CLOSED  All emails with the attachment of the prelimin...
# 32432  20-4254  CLOSED  All emails with the attachment of the prelimin...
# 32433  20-4254  CLOSED  All emails with the attachment of the prelimin...
# 32434  20-4254  CLOSED  All emails with the attachment of the prelimin...
#
#                                                    depts  \
# 0                                       Code Enforcement
# 1       Department of Real Estate and Airport Management
# 2                                             City Clerk
# 3       Department of Real Estate and Airport Management
# 4                                       Code Enforcement
# ...                                                  ...
# 32430  City Attorney, City Council District 4, Develo...
# 32431  City Attorney, City Council District 4, Develo...
# 32432  City Attorney, City Council District 4, Develo...
# 32433  City Attorney, City Council District 4, Develo...
# 32434  City Attorney, City Council District 4, Develo...
#
#                                                     docs                 poc  \
# 0      title,link
# 5040 ShorehamPlace building permits...    Ginger Rodriguez
# 1                                                            Jeffrey Wallace
# 2      title,link
# http://www.sandiego.gov/park-and-re...  Mailei Ross-Cerezo
# 3                                                            Jeffrey Wallace
# 4      title,link
# Site Plan - 11943 El Camino Real.pd...    Ginger Rodriguez
# ...                                                  ...                 ...
# 32430  title,link
# "Attachment to Email A, Forensic Re...      Angela Laurita
# 32431  title,link
# "Attachment to Email A, Forensic Re...      Angela Laurita
# 32432  title,link
# "Attachment to Email A, Forensic Re...      Angela Laurita
# 32433  title,link
# "Attachment to Email A, Forensic Re...      Angela Laurita
# 32434  title,link
# "Attachment to Email A, Forensic Re...      Angela Laurita
#
#                                                     msgs  \
# 0      title,item,time
# "Request Closed
# Public",02. Re...
# 1      title,item,time
# "Request Published
# Public",,"D...
# 2      title,item,time
# "Request Closed
# Public",Still ...
# 3      title,item,time
# "Request Closed
# Public",02. Re...
# 4      title,item,time
# "Request Closed
# Public",02. Re...
# ...                                                  ...
# 32430  title,item,time
# "Request Published
# Public",,"J...
# 32431  title,item,time
# "Request Published
# Public",,"J...
# 32432  title,item,time
# "Request Published
# Public",,"J...
# 32433  title,item,time
# "Request Published
# Public",,"J...
# 32434  title,item,time
# "Request Published
# Public",,"J...
#
#                                                  docs_df  \
# 0                                           title  \
# ...
# 1                                                   None
# 2                                                    ...
# 3                                                   None
# 4                                        title  \
# 0  ...
# ...                                                  ...
# 32430                                                ...
# 32431                                                ...
# 32432                                                ...
# 32433                                                ...
# 32434                                                ...
#
#                                                  msgs_df                date  \
# 0                                title               ...    December 7, 2015
# 1                                title               ...    December 7, 2015
# 2                                title  \
# 0         R...    December 7, 2015
# 3                                title               ...    December 7, 2015
# 4                                 title              ...    December 7, 2015
# ...                                                  ...                 ...
# 32430                                       title  \
# ...  September 23, 2020
# 32431                                       title  \
# ...  September 23, 2020
# 32432                                       title  \
# ...  September 23, 2020
# 32433                                       title  \
# ...  September 23, 2020
# 32434                                       title  \
# ...  September 23, 2020
#
#        via                                               dept
# 0      web                                   Code Enforcement
# 1      web   Department of Real Estate and Airport Management
# 2      web                                         City Clerk
# 3      web   Department of Real Estate and Airport Management
# 4      web                                   Code Enforcement
# ...    ...                                                ...
# 32430  web                              Department of Finance
# 32431  web  Deputy Chief Operating Officer - Smart & Susta...
# 32432  web                           Office of Sustainability
# 32433  web                            Homelessness Strategies
# 32434  web  Deputy Chief Operating Officer - General Services
#
# [32435 rows x 12 columns]

# %%
test_df_depts.value_counts('dept')[lambda x: x.index.str.contains('Police', case=False)]
# Out:
# dept
# Police                            6886
# Commission on Police Practices      51
# dtype: int64

# %%
# Find requests whose department(s) contain the given substring, case insensitive
dept = 'Chief Operating Officer'
test_df[test_df['depts'].str.contains(dept, case=False)]
# Out:
#             id  status                                               desc  \
# 30     15-1840  CLOSED  Writings and communications related to Sai Kir...
# 351     16-212  CLOSED  Records relating to SAP software agreement and...
# 3397    17-327  CLOSED  Location: Intersection of Canon St. & Catalina...
# 3730    17-660  CLOSED  1.      Please provide a copy of the executed ...
# 3731    17-661  CLOSED  Please provide all conflict of interest disclo...
# ...        ...     ...                                                ...
# 25496  21-1956  CLOSED  Hello,
# Pursuant to the California Public Recor...
# 25701  21-2169  CLOSED  Hello,
# Pursuant to the California Public Recor...
# 25870  21-2338  CLOSED  Hello,
# Pursuant to the California Public Recor...
# 27701  21-4226  CLOSED  Hello,
#
# Pursuant to the California Public Reco...
# 28075  21-4618  CLOSED  Our department is looking for a copy of the si...
#
#                                                    depts  \
# 30     Deputy Chief Operating Officer - Infrastructur...
# 351    Deputy Chief Operating Officer - Infrastructur...
# 3397   Deputy Chief Operating Officer - Infrastructur...
# 3730   Information Technology, Deputy Chief Operating...
# 3731   Deputy Chief Operating Officer - Infrastructur...
# ...                                                  ...
# 25496              Office of the Chief Operating Officer
# 25701              Office of the Chief Operating Officer
# 25870       Mayor, Office of the Chief Operating Officer
# 27701              Office of the Chief Operating Officer
# 28075              Office of the Chief Operating Officer
#
#                                                     docs                poc  \
# 30     title,link
# Letter to Finch (CCPRA 2015-1840).p...  Jacqueline Palmer
# 351                                                               Erin Noel
# 3397                                                           Travis Brady
# 3730   title,link
# 17-660 Email Results_Redacted.pdf,h...  Jacqueline Palmer
# 3731   title,link
# H166584 Exhibit H Signed_02-29-16.p...       Travis Brady
# ...                                                  ...                ...
# 25496  title,link
# Pages from 20-296_COO Emails re 101...     Angela Laurita
# 25701  title,link
# 21-2169_RVilla Emails_09-2016_Redac...     Angela Laurita
# 25870                                                        Angela Laurita
# 27701  title,link
# PRAR 21-4226 - KM Calendar_Redacted...     Angela Laurita
# 28075                                                      Ginger Rodriguez
#
#                                                     msgs  \
# 30     title,item,time
# "Request Closed   Hide
# Public"...
# 351    title,item,time
# "Request Closed
# Public","02. R...
# 3397   title,item,time
# "Request Published
# Public",,"F...
# 3730   title,item,time
# "Request Published
# Public",,"J...
# 3731   title,item,time
# "Request Published
# Public",,"A...
# ...                                                  ...
# 25496  title,item,time
# "Request Published
# Public",,"M...
# 25701  title,item,time
# "Request Published
# Public",,"J...
# 25870  title,item,time
# "Request Published
# Public",,"M...
# 27701  title,item,time
# "Request Published
# Public",,"S...
# 28075  title,item,time
# "Request Published
# Public",,"S...
#
#                                                  docs_df  \
# 30                                                   ...
# 351                                                 None
# 3397                                                None
# 3730                                                 ...
# 3731                                                 ...
# ...                                                  ...
# 25496                                                ...
# 25701                                          title ...
# 25870                                               None
# 27701                                       title  \
# ...
# 28075                                               None
#
#                                                  msgs_df              date  \
# 30                               title  \
# 0  Request ...  December 9, 2015
# 351                              title  \
# 0         R...  February 8, 2016
# 3397                             title  \
# 0      Requ...  February 9, 2017
# 3730                              title  \
# 0       Re...    March 20, 2017
# 3731                              title  \
# 0       Re...    March 20, 2017
# ...                                                  ...               ...
# 25496                            title  \
# 0      Requ...    April 16, 2021
# 25701                            title  \
# 0      Requ...    April 26, 2021
# 25870                            title  \
# 0      Requ...       May 2, 2021
# 27701                            title  \
# 0      Requ...    August 4, 2021
# 28075                            title  \
# 0      Requ...   August 27, 2021
#
#        via
# 30     web
# 351    web
# 3397   web
# 3730   web
# 3731   web
# ...    ...
# 25496  web
# 25701  web
# 25870  web
# 27701  web
# 28075  web
#
# [138 rows x 11 columns]

# %%
test_df.loc[100]['msgs_df']
# Out:
#                           title  \
# 0         Request Closed
# Public
# 1       Request Reopened
# Public
# 2         Request Closed
# Public
# 3   Document(s) Released
# Public
# 4      Request Published
# Public
# 5  Department Assignment
# Public
# 6         Request Opened
# Public
#
#                                                 item  \
# 0  02. Released
# All responsive documents have bee...
# 1
# 2  02. Released
# All responsive documents have bee...
# 3     3010 Science Park Dr open building permits.pdf
# 4
# 5                               Development Services
# 6                           Request received via web
#
#                         time  \
# 0    January 3, 2016, 1:04pm
# 1    January 3, 2016, 1:02pm
# 2   January 3, 2016, 12:59pm
# 3   January 3, 2016, 12:58pm
# 4  December 22, 2015, 9:36am
# 5  December 22, 2015, 9:36am
# 6  December 22, 2015, 9:36am
#
#                                                   by             time_dt
# 0                                   Ginger Rodriquez 2016-01-03 13:04:00
# 1                                   Ginger Rodriquez 2016-01-03 13:02:00
# 2                                   Ginger Rodriquez 2016-01-03 12:59:00
# 3                                   Ginger Rodriquez 2016-01-03 12:58:00
# 4                                                    2015-12-22 09:36:00
# 5  Lea Fields-Bernard, Public Records Administrat... 2015-12-22 09:36:00
# 6  Lea Fields-Bernard, Public Records Administrat... 2015-12-22 09:36:00

# %%
def get_open_time(msgs):
    request_published = msgs[lambda df: df['title'].str.contains('Opened')].sort_values(by='time_dt', ignore_index=True)
    return request_published.loc[0]['time_dt']

test_df['open_time'] = test_df['msgs_df'].apply(get_submission_time)
test_df.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/core/indexes/range.py in get_loc(self, key, method, tolerance)
#     354                 try:
# --> 355                     return self._range.index(new_key)
#     356                 except ValueError as err:
#
# ValueError: 0 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /var/folders/cw/463xpk7n6hndd1xjb9kt_whm0000gn/T/ipykernel_19251/3475820311.py in <module>
#       3     return request_published.loc[0]['time_dt']
#       4
# ----> 5 test_df['open_time'] = test_df['msgs_df'].apply(get_submission_time)
#       6 test_df.head()
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    4210             else:
#    4211                 values = self.astype(object)._values
# -> 4212                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4213
#    4214         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# /var/folders/cw/463xpk7n6hndd1xjb9kt_whm0000gn/T/ipykernel_19251/567425166.py in get_submission_time(msgs)
#       1 def get_submission_time(msgs):
#       2     request_published = msgs.query('title == "Request Published Public"').sort_values(by='time_dt', ignore_index=True)
# ----> 3     return request_published.loc[0]['time_dt']
#       4
#       5 test_df['sub_time'] = test_df['msgs_df'].apply(get_submission_time)
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#     877
#     878             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 879             return self._getitem_axis(maybe_callable, axis=axis)
#     880
#     881     def _is_scalar_access(self, key: Tuple):
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1108         # fall thru to straight lookup
#    1109         self._validate_key(key, axis)
# -> 1110         return self._get_label(key, axis=axis)
#    1111
#    1112     def _get_slice_axis(self, slice_obj: slice, axis: int):
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/core/indexing.py in _get_label(self, label, axis)
#    1057     def _get_label(self, label, axis: int):
#    1058         # GH#5667 this will fail if the label is not present in the axis.
# -> 1059         return self.obj.xs(label, axis=axis)
#    1060
#    1061     def _handle_lowerdim_multi_index_axis0(self, tup: Tuple):
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/core/generic.py in xs(self, key, axis, level, drop_level)
#    3489             loc, new_index = self.index.get_loc_level(key, drop_level=drop_level)
#    3490         else:
# -> 3491             loc = self.index.get_loc(key)
#    3492
#    3493             if isinstance(loc, np.ndarray):
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/core/indexes/range.py in get_loc(self, key, method, tolerance)
#     355                     return self._range.index(new_key)
#     356                 except ValueError as err:
# --> 357                     raise KeyError(key) from err
#     358             raise KeyError(key)
#     359         return super().get_loc(key, method=method, tolerance=tolerance)
#
# KeyError: 0

# %%
test_df.value_counts('via')
# Out:
# via
# web      26220
# email     1855
# mail       517
# phone       99
# fax         46
# dtype: int64

# %%
# TODO: Extract department assignment additions and removals based on message history
def find_dept_assign(msgs):
    dept_assign = msgs[lambda df: df['title'].str.contains('Department')]
    
    dept_assign_added = dept_assign[lambda df: df['item'].str.contains('Added:')]
    dept_assign_removed = dept_assign[lambda df: df['item'].str.contains('Removed:')]

test_df.loc[1]['msgs_df']
# Out:
#                           title                      item  \
# 0      Request Published
# Public
# 1         Request Closed
# Public              02. Released
# 2  Department Assignment
# Public        Real Estate Assets
# 3         Request Opened
# Public  Request received via web
# 4      Request Published
# Public
#
#                         time  \
# 0  December 16, 2015, 9:54am
# 1  December 15, 2015, 7:12am
# 2   December 7, 2015, 5:22pm
# 3   December 7, 2015, 5:22pm
# 4   December 7, 2015, 5:22pm
#
#                                                   by             time_dt
# 0                                    Jeffrey Wallace 2015-12-16 09:54:00
# 1                                    Jeffrey Wallace 2015-12-15 07:12:00
# 2                                                    2015-12-07 17:22:00
# 3  Lea Fields-Bernard, Public Records Administrat... 2015-12-07 17:22:00
# 4                                                    2015-12-07 17:22:00
