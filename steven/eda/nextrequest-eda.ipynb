# %% [markdown]
# # NextRequest data cleaning and EDA
# *Author: Steven Yuan*
#
# This notebook is used to perform preliminary EDA on NextRequest data using pandas
#
# ## TO-DO
# - Write a procedure to extract all the documents that are attached to a request based on the message history
# - Significance test to determine if the response times for police-related requests is different than response times for non-police related requests
# - Some requests were re-opened/re-closed, how do we factor that into our analysis?
# - Test EDA functions on different datasets once they are scraped

# %%
import pandas as pd
import numpy as np
from io import StringIO
import zipfile

from nextrequest_eda_utils import *

# %%
sd = pd.read_csv(zipfile.ZipFile('../data/sd_requests.zip', 'r').open('sd_requests.csv'))
sd.head()
# Out:
#         id  status                                               desc  \
# 0  15-1810  CLOSED  Notices of Violation/Notice to Comply, fire in...
# 1  15-1811  CLOSED       The October 2015 monthly report for SeaWorld
# 2  15-1812  CLOSED  Records related to the following BIDS:  Adams ...
# 3  15-1813  CLOSED  Historical lease payments made by SeaWorld to ...
# 4  15-1814  CLOSED  Open violations, variances, ordinances, approv...
#
#                        date                                             depts  \
# 0  December 7, 2015 via web                                  Code Enforcement
# 1  December 7, 2015 via web  Department of Real Estate and Airport Management
# 2  December 7, 2015 via web                                        City Clerk
# 3  December 7, 2015 via web  Department of Real Estate and Airport Management
# 4  December 7, 2015 via web                                  Code Enforcement
#
#                                                 docs                 poc  \
# 0  title,link\n5040 ShorehamPlace building permit...    Ginger Rodriguez
# 1                                                NaN     Jeffrey Wallace
# 2  title,link\nhttp://www.sandiego.gov/park-and-r...  Mailei Ross-Cerezo
# 3                                                NaN     Jeffrey Wallace
# 4  title,link\nSite Plan - 11943 El Camino Real.p...    Ginger Rodriguez
#
#                                                 msgs
# 0  title,item,time\n"Request Closed\nPublic",02. ...
# 1  title,item,time\n"Request Published\nPublic",,...
# 2  title,item,time\n"Request Closed\nPublic",Stil...
# 3  title,item,time\n"Request Closed\nPublic",02. ...
# 4  title,item,time\n"Request Closed\nPublic",02. ...

# %%
sd_clean = nextrequest_df_clean(sd, debug=True)
# Out:
# fillna complete
# docs_df complete
# msgs_df complete
# date-via split complete
# time-by split in msgs complete

# %%
sd_clean.shape[0]
# Out:
# 28848

# %%
sd_clean.head()
# Out:
#         id  status                                               desc  \
# 0  15-1810  CLOSED  Notices of Violation/Notice to Comply, fire in...
# 1  15-1811  CLOSED       The October 2015 monthly report for SeaWorld
# 2  15-1812  CLOSED  Records related to the following BIDS:  Adams ...
# 3  15-1813  CLOSED  Historical lease payments made by SeaWorld to ...
# 4  15-1814  CLOSED  Open violations, variances, ordinances, approv...
#
#                                               depts  \
# 0                                  Code Enforcement
# 1  Department of Real Estate and Airport Management
# 2                                        City Clerk
# 3  Department of Real Estate and Airport Management
# 4                                  Code Enforcement
#
#                                                 docs                 poc  \
# 0  title,link
# 5040 ShorehamPlace building permits...    Ginger Rodriguez
# 1                                                        Jeffrey Wallace
# 2  title,link
# http://www.sandiego.gov/park-and-re...  Mailei Ross-Cerezo
# 3                                                        Jeffrey Wallace
# 4  title,link
# Site Plan - 11943 El Camino Real.pd...    Ginger Rodriguez
#
#                                                 msgs  \
# 0  title,item,time
# "Request Closed
# Public",02. Re...
# 1  title,item,time
# "Request Published
# Public",,"D...
# 2  title,item,time
# "Request Closed
# Public",Still ...
# 3  title,item,time
# "Request Closed
# Public",02. Re...
# 4  title,item,time
# "Request Closed
# Public",02. Re...
#
#                                              docs_df  \
# 0                                       title  \
# ...
# 1
# 2                                                ...
# 3
# 4                                    title  \
# 0  ...
#
#                                              msgs_df              date  \
# 0                            title               ...  December 7, 2015
# 1                            title               ...  December 7, 2015
# 2                            title  \
# 0         R...  December 7, 2015
# 3                            title               ...  December 7, 2015
# 4                             title              ...  December 7, 2015
#
#        via    date_dt
# 0  via web 2015-12-07
# 1  via web 2015-12-07
# 2  via web 2015-12-07
# 3  via web 2015-12-07
# 4  via web 2015-12-07

# %%
sd_clean.loc[4]['msgs_df']
# Out:
#                            title                                  item  \
# 0          Request Closed
# Public                          02. Released
# 1    Document(s) Released
# Public  Site Plan - 11943 El Camino Real.pdf
# 2        Request Reopened
# Public
# 3          Request Closed
# Public                          02. Released
# 4    Document(s) Released
# Public           15-1814 Fire Responsive.pdf
# 5        Request Reopened
# Public
# 6          Request Closed
# Public                          02. Released
# 7        Request Reopened
# Public
# 8          Request Closed
# Public                          02. Released
# 9          Request Closed
# Public                          02. Released
# 10   Document(s) Released
# Public  Site Plan - 11943 El Camino Real.pdf
# 11      Request Published
# Public
# 12         Request Opened
# Public              Request received via web
# 13  Department Assignment
# Public                      Code Enforcement
# 14      Request Published
# Public
#
#                           time  \
# 0   December 24, 2015, 10:34am
# 1   December 24, 2015, 10:33am
# 2   December 24, 2015, 10:32am
# 3    December 24, 2015, 8:09am
# 4    December 24, 2015, 8:09am
# 5    December 24, 2015, 8:02am
# 6    December 17, 2015, 4:00pm
# 7    December 17, 2015, 3:56pm
# 8    December 17, 2015, 3:54pm
# 9    December 17, 2015, 3:52pm
# 10   December 17, 2015, 3:51pm
# 11    December 8, 2015, 9:20am
# 12    December 7, 2015, 5:39pm
# 13    December 7, 2015, 5:39pm
# 14    December 7, 2015, 5:39pm
#
#                                                    by             time_dt
# 0                                    Ginger Rodriquez 2015-12-24 10:34:00
# 1                                    Ginger Rodriquez 2015-12-24 10:33:00
# 2                                    Ginger Rodriquez 2015-12-24 10:32:00
# 3                                    Ginger Rodriquez 2015-12-24 08:09:00
# 4                                    Ginger Rodriquez 2015-12-24 08:09:00
# 5                       Amanda Alvarado, Senior Clerk 2015-12-24 08:02:00
# 6                                    Ginger Rodriquez 2015-12-17 16:00:00
# 7                                    Ginger Rodriquez 2015-12-17 15:56:00
# 8                                    Ginger Rodriquez 2015-12-17 15:54:00
# 9                                    Ginger Rodriquez 2015-12-17 15:52:00
# 10                                   Ginger Rodriquez 2015-12-17 15:51:00
# 11  Lea Fields-Bernard, Public Records Administrat... 2015-12-08 09:20:00
# 12  Lea Fields-Bernard, Public Records Administrat... 2015-12-07 17:39:00
# 13                                                    2015-12-07 17:39:00
# 14                                                    2015-12-07 17:39:00

# %%
# Query for info about a specific request
request_id = '"17-22"'
sd_clean.query('id == ' + request_id).iloc[0]['msgs_df']
# Out:
#                              title  \
# 0         Request Published
# Public
# 1            Request Closed
# Public
# 2      Document(s) Released
# Public
# 3      Document(s) Released
# Public
# 4      Document(s) Released
# Public
# ...                            ...
# 1112   Document(s) Released
# Public
# 1113   Document(s) Released
# Public
# 1114   Document(s) Released
# Public
# 1115  Department Assignment
# Public
# 1116         Request Opened
# Public
#
#                                                    item  \
# 0
# 1     02. Released
# All responsive documents have bee...
# 2                                   20160315_131321.jpg
# 3                                   20160315_131307.jpg
# 4                                   20160315_131230.jpg
# ...                                                 ...
# 1112                                20160307_155141.jpg
# 1113                                20160307_155139.jpg
# 1114                     7411 Hillside Drive Photos.pdf
# 1115                                   Code Enforcement
# 1116                           Request received via web
#
#                           time  \
# 0     January 16, 2017, 4:10pm
# 1     January 13, 2017, 4:06pm
# 2     January 13, 2017, 4:00pm
# 3     January 13, 2017, 4:00pm
# 4     January 13, 2017, 4:00pm
# ...                        ...
# 1112  January 13, 2017, 3:54pm
# 1113  January 13, 2017, 3:54pm
# 1114  January 13, 2017, 3:54pm
# 1115   January 6, 2017, 3:23pm
# 1116  January 4, 2017, 10:08am
#
#                                                      by             time_dt
# 0                                                       2017-01-16 16:10:00
# 1                                      Ginger Rodriquez 2017-01-13 16:06:00
# 2                                      Ginger Rodriquez 2017-01-13 16:00:00
# 3                                      Ginger Rodriquez 2017-01-13 16:00:00
# 4                                      Ginger Rodriquez 2017-01-13 16:00:00
# ...                                                 ...                 ...
# 1112                                   Ginger Rodriquez 2017-01-13 15:54:00
# 1113                                   Ginger Rodriquez 2017-01-13 15:54:00
# 1114                                   Ginger Rodriquez 2017-01-13 15:54:00
# 1115  Lea Fields-Bernard, Public Records Administrat... 2017-01-06 15:23:00
# 1116                                                    2017-01-04 10:08:00
#
# [1117 rows x 5 columns]

# %%
# Find request descriptions with the given substring, case insensitive
desc = 'Padres'
test_df[test_df['desc'].str.contains(desc, case=False)]

# %%
# Find requests whose department(s) contain the given substring, case insensitive
dept_search = 'police'
sd_clean[lambda df: df['depts'].str.contains(dept_search, case=False)]
# Out:
#             id  status                                               desc  \
# 7      15-1817  CLOSED  File materials related to:
# P12010041171
# P12050...
# 49     15-1859  CLOSED  All records related to the demographic study c...
# 65     15-1875  CLOSED  Reports related to incident of 11/11/2015 wher...
# 81     15-1891  CLOSED  Communications by the City of San Diego regard...
# 121    15-1931  CLOSED  Vehicle Stop Data for period September 1, 2015...
# ...        ...     ...                                                ...
# 28838  21-5544  CLOSED  Dan you tell me when San Diego Police Officer ...
# 28839  21-5550  CLOSED  I request any police reports involving inciden...
# 28840  21-5552  CLOSED  The request is for the time of the towing call...
# 28845  21-5584  CLOSED           request for call for service
#
# 2110020816
# 28846  21-5588  CLOSED         request for call for service
#
# E20050048015
#
#         depts                                               docs  \
# 7      Police
# 49     Police
# 65     Police
# 81     Police
# 121    Police
# ...       ...                                                ...
# 28838  Police
# 28839  Police
# 28840  Police
# 28845  Police  title,link
# 2110020816_Redacted.pdf,https://san...
# 28846  Police  title,link
# E20050048015_Redacted.pdf,https://s...
#
#                       poc                                               msgs  \
# 7      Humberto Hernandez  title,item,time
# "Request Closed
# Public",02c. R...
# 49     Humberto Hernandez  title,item,time
# "Request Closed   Hide
# Public"...
# 65     Humberto Hernandez  title,item,time
# "Request Closed
# Public","02. R...
# 81     Humberto Hernandez  title,item,time
# "Request Closed
# Public",Still ...
# 121    Humberto Hernandez  title,item,time
# "Request Closed
# Public",Still ...
# ...                   ...                                                ...
# 28838      Angela Laurita  title,item,time
# "Request Published
# Public",,"N...
# 28839      Angela Laurita  title,item,time
# "Request Published
# Public",,"O...
# 28840      Angela Laurita  title,item,time
# "Request Published
# Public",,"O...
# 28845      Lori Hernandez  title,item,time
# "Request Published
# Public",,"N...
# 28846      Lori Hernandez  title,item,time
# "Request Published
# Public",,"N...
#
#                                                  docs_df  \
# 7
# 49
# 65
# 81
# 121
# ...                                                  ...
# 28838
# 28839
# 28840
# 28845                       title                    ...
# 28846                         title  \
# 0  E2005004801...
#
#                                                  msgs_df               date  \
# 7                                title               ...   December 7, 2015
# 49                               title  \
# 0  Request ...  December 11, 2015
# 65                               title  \
# 0         R...  December 15, 2015
# 81                               title               ...  December 17, 2015
# 121                              title  \
# 0         R...  December 28, 2015
# ...                                                  ...                ...
# 28838                            title  \
# 0      Requ...   October 26, 2021
# 28839                            title  \
# 0      Requ...   October 27, 2021
# 28840                            title  \
# 0      Requ...   October 27, 2021
# 28845                            title  \
# 0      Requ...   October 28, 2021
# 28846                            title  \
# 0      Requ...   October 28, 2021
#
#            via    date_dt           open_time          close_time  \
# 7      via web 2015-12-07 2015-12-08 11:40:00 2015-12-21 10:48:00
# 49     via web 2015-12-11 2015-12-14 18:07:00 2016-01-12 10:06:00
# 65     via web 2015-12-15 2015-12-16 11:32:00 2016-01-13 07:40:00
# 81     via web 2015-12-17 2015-12-18 10:30:00 2015-12-28 15:26:00
# 121    via web 2015-12-28 2015-12-28 10:56:00 2015-12-31 13:40:00
# ...        ...        ...                 ...                 ...
# 28838  via web 2021-10-26 2021-10-26 21:34:00 2021-10-29 07:49:00
# 28839  via web 2021-10-27 2021-10-27 11:12:00 2021-10-27 12:50:00
# 28840  via web 2021-10-27 2021-10-27 12:22:00 2021-10-28 15:00:00
# 28845  via web 2021-10-28 2021-10-28 13:56:00 2021-10-29 13:59:00
# 28846  via web 2021-10-28 2021-10-28 14:52:00 2021-10-29 14:01:00
#
#                   resp
# 7     12 days 23:08:00
# 49    28 days 15:59:00
# 65    27 days 20:08:00
# 81    10 days 04:56:00
# 121    3 days 02:44:00
# ...                ...
# 28838  2 days 10:15:00
# 28839  0 days 01:38:00
# 28840  1 days 02:38:00
# 28845  1 days 00:03:00
# 28846  0 days 23:09:00
#
# [6905 rows x 15 columns]

# %%
# Get open and close times for each request
sd_clean['open_time'] = sd_clean['msgs_df'].apply(get_open_time)
print('open_time done')
sd_clean['close_time'] = sd_clean['msgs_df'].apply(get_close_time)
print('close_time done')
# Out:
# open_time done
# close_time done

# %%
sd_clean['resp'] = sd_clean['close_time'] - sd_clean['open_time']
sd_clean.head()
# Out:
#         id  status                                               desc  \
# 0  15-1810  CLOSED  Notices of Violation/Notice to Comply, fire in...
# 1  15-1811  CLOSED       The October 2015 monthly report for SeaWorld
# 2  15-1812  CLOSED  Records related to the following BIDS:  Adams ...
# 3  15-1813  CLOSED  Historical lease payments made by SeaWorld to ...
# 4  15-1814  CLOSED  Open violations, variances, ordinances, approv...
#
#                                               depts  \
# 0                                  Code Enforcement
# 1  Department of Real Estate and Airport Management
# 2                                        City Clerk
# 3  Department of Real Estate and Airport Management
# 4                                  Code Enforcement
#
#                                                 docs                 poc  \
# 0  title,link
# 5040 ShorehamPlace building permits...    Ginger Rodriguez
# 1                                                        Jeffrey Wallace
# 2  title,link
# http://www.sandiego.gov/park-and-re...  Mailei Ross-Cerezo
# 3                                                        Jeffrey Wallace
# 4  title,link
# Site Plan - 11943 El Camino Real.pd...    Ginger Rodriguez
#
#                                                 msgs  \
# 0  title,item,time
# "Request Closed
# Public",02. Re...
# 1  title,item,time
# "Request Published
# Public",,"D...
# 2  title,item,time
# "Request Closed
# Public",Still ...
# 3  title,item,time
# "Request Closed
# Public",02. Re...
# 4  title,item,time
# "Request Closed
# Public",02. Re...
#
#                                              docs_df  \
# 0                                       title  \
# ...
# 1
# 2                                                ...
# 3
# 4                                    title  \
# 0  ...
#
#                                              msgs_df              date  \
# 0                            title               ...  December 7, 2015
# 1                            title               ...  December 7, 2015
# 2                            title  \
# 0         R...  December 7, 2015
# 3                            title               ...  December 7, 2015
# 4                             title              ...  December 7, 2015
#
#        via    date_dt           open_time          close_time             resp
# 0  via web 2015-12-07 2015-12-07 17:08:00 2015-12-17 16:34:00  9 days 23:26:00
# 1  via web 2015-12-07 2015-12-07 17:22:00 2015-12-15 07:12:00  7 days 13:50:00
# 2  via web 2015-12-07 2015-12-07 17:29:00 2015-12-22 11:32:00 14 days 18:03:00
# 3  via web 2015-12-07 2015-12-07 17:33:00 2015-12-15 07:10:00  7 days 13:37:00
# 4  via web 2015-12-07 2015-12-07 17:39:00 2015-12-24 10:34:00 16 days 16:55:00

# %%
dept_search = r'police|sheriff'
sd_clean[lambda df: df['depts'].str.contains(dept_search, case=False)]['resp'].mean()
# Out:
# Timedelta('13 days 09:46:00.469225199')

# %%
dept_search = r'commission'
sd_clean[lambda df: df['depts'].str.contains(dept_search, case=False)]
# Out:
#             id  status                                               desc  \
# 664     16-529  CLOSED  I am writing to request documents related to “...
# 915     16-780  CLOSED  All records related to or arising out of: (i) ...
# 3205    17-135  CLOSED  Saranya Kalai
# Associate Attorney
# Solomon Salts...
# 3434    17-364  CLOSED  Dear Sir or Madam,
# I am writing to request all...
# 3888    17-818  CLOSED  Records related to Ranch Valley Farms/Rancho V...
# ...        ...     ...                                                ...
# 27791  21-4322  CLOSED  Municipal Code updates. I often use the Munici...
# 27935  21-4470  CLOSED  To Whom It May Concern/Custodian of Personnel ...
# 28021  21-4560  CLOSED  August 18, 2021
# San Diego Police Department
# Re...
# 28065  21-4606  CLOSED  The agreement that represents the written "bus...
# 28443  21-5014  CLOSED  I need a copy of the Appeal that was filed in ...
#
#                                            depts  \
# 664                          Planning Commission
# 915                          Planning Commission
# 3205                         Planning Commission
# 3434                         Planning Commission
# 3888   Development Services, Planning Commission
# ...                                          ...
# 27791  Development Services, Planning Commission
# 27935             Commission on Police Practices
# 28021     Police, Commission on Police Practices
# 28065  Development Services, Planning Commission
# 28443  Development Services, Planning Commission
#
#                                                     docs               poc  \
# 664                                                       Ginger Rodriguez
# 915                                                       Ginger Rodriguez
# 3205   title,link
# PRA 17-135 Conditional Use Permit 6...  Ginger Rodriguez
# 3434                                                        Angela Laurita
# 3888                                                        Angela Laurita
# ...                                                  ...               ...
# 27791  title,link
# https://www.sandiego.gov/city-clerk...  Ginger Rodriguez
# 27935                                                       Angela Laurita
# 28021                                                       Angela Laurita
# 28065  title,link
# https://docs.sandiego.gov/council_r...  Ginger Rodriguez
# 28443  title,link
# 622996 Appeal Invoice.pdf,https://s...  Ginger Rodriguez
#
#                                                     msgs  \
# 664    title,item,time
# "Request Published
# Public",,"A...
# 915    title,item,time
# "Request Published
# Public",,"M...
# 3205   title,item,time
# "Request Published
# Public",,"J...
# 3434   title,item,time
# "Request Published
# Public",,"F...
# 3888   title,item,time
# "Request Published
# Public",,"M...
# ...                                                  ...
# 27791  title,item,time
# "Request Published
# Public",,"A...
# 27935  title,item,time
# "Request Published
# Public",,"S...
# 28021  title,item,time
# "Request Published
# Public",,"A...
# 28065  title,item,time
# "Request Published
# Public",,"S...
# 28443  title,item,time
# "Request Published
# Public",,"O...
#
#                                                  docs_df  \
# 664
# 915
# 3205                                                 ...
# 3434
# 3888
# ...                                                  ...
# 27791                                                ...
# 27935
# 28021
# 28065                                                ...
# 28443                                                ...
#
#                                                  msgs_df                date  \
# 664                              title  \
# 0      Requ...      March 23, 2016
# 915                              title  \
# 0      Requ...      April 22, 2016
# 3205                             title  \
# 0      Requ...    January 18, 2017
# 3434                             title  \
# 0      Requ...   February 14, 2017
# 3888                             title  \
# 0      Requ...       April 5, 2017
# ...                                                  ...                 ...
# 27791                            title  \
# 0      Requ...     August 10, 2021
# 27935                            title  \
# 0      Requ...     August 18, 2021
# 28021                            title  \
# 0      Requ...     August 23, 2021
# 28065                                     title  \
# 0 ...     August 26, 2021
# 28443                            title  \
# 0      Requ...  September 22, 2021
#
#             via    date_dt           open_time          close_time  \
# 664     via web 2016-03-23 2016-03-23 09:49:00 2016-04-08 14:31:00
# 915     via web 2016-04-22 2016-04-22 10:26:00 2016-05-16 16:08:00
# 3205    via web 2017-01-18 2017-01-18 13:24:00 2017-01-27 17:05:00
# 3434    via web 2017-02-14 2017-02-14 14:42:00 2017-02-24 16:12:00
# 3888   via mail 2017-04-05 2017-04-05 15:22:00 2017-05-12 12:05:00
# ...         ...        ...                 ...                 ...
# 27791   via web 2021-08-10 2021-08-10 13:21:00 2021-08-12 13:54:00
# 27935   via web 2021-08-18 2021-08-18 16:43:00 2021-09-07 08:24:00
# 28021  via mail 2021-08-23 2021-08-24 10:38:00 2021-08-24 11:50:00
# 28065   via web 2021-08-26 2021-08-26 15:18:00 2021-09-21 13:24:00
# 28443   via web 2021-09-22 2021-09-22 11:38:00 2021-10-28 15:30:00
#
#                   resp
# 664   16 days 04:42:00
# 915   24 days 05:42:00
# 3205   9 days 03:41:00
# 3434  10 days 01:30:00
# 3888  36 days 20:43:00
# ...                ...
# 27791  2 days 00:33:00
# 27935 19 days 15:41:00
# 28021  0 days 01:12:00
# 28065 25 days 22:06:00
# 28443 36 days 03:52:00
#
# [183 rows x 15 columns]

# %%
sd_depts = melt_depts(sd_clean)

# %%
# Out:
# Timedelta('24 days 16:48:34.721515504')

# %%
sd_depts.value_counts('dept')
# Out:
# dept
# Police                                               6886
# Development Services                                 4832
# Public Records Administration                        4621
# Code Enforcement                                     2038
# Fire-Rescue                                          1755
#                                                      ...
# Commission on Gang Prevention and Intervention          5
# Deputy Chief Operating Officer - General Services       5
# Compliance Department                                   4
# Human Relations Commission                              4
# Citizens Assistance                                     4
# Length: 71, dtype: int64

# %%
len(list(np.sort(sd_depts['dept'].unique())))
# Out:
# 71

# %%
# TODO: Extract department assignment additions and removals based on message history
def get_dept_assign(msgs, get_time=False):
    if msgs is None: return None

    dept_assign = msgs[lambda df: df['title'].str.contains('Department')].sort_values(by='time_dt', ignore_index=True)
    
    if dept_assign.empty: return None

    # TODO: Add option to include time information
    dept_assign_init = dept_assign[  # Initial department assignment
            lambda df: ~df['item'].str.contains(r'Added|Removed')
        ]['item'].to_numpy()
    dept_assign_added = dept_assign[  # Departments that were added
            lambda df: df['item'].str.contains('Added')
        ]['item'].str.split(
            r'Added: |Removed: '
        ).str[1].str.strip(' .').str.split(', ').to_numpy()
    dept_assign_removed = dept_assign[  # Departments that were removed
            lambda df: df['item'].str.contains('Removed')
        ]['item'].str.split(
            'Removed: '
        ).str[-1].str.strip(' .').str.split(', ').to_numpy()
    
    return {
        'dept_added': list(set([dept for l in list(dept_assign_added).append(dept_assign_init) for dept in l])),
        'dept_removed': list(set([dept for l in list(dept_assign_removed) for dept in l]))
        }

# %%
testtest = sd_clean['msgs_df'].apply(lambda df: len(df[df['title'].str.contains('Department')])).sort_values(ascending=False)

# %%
testtest.head(20)
# Out:
# 22065    53
# 21905    53
# 7386     50
# 14991    50
# 14983    49
# 14984    47
# 19196    45
# 19496    44
# 14988    44
# 14986    43
# 14166    42
# 14985    40
# 14987    38
# 14989    36
# 26149    30
# 20013    27
# 6398     27
# 5607     26
# 20200    25
# 22047    25
# Name: msgs_df, dtype: int64

# %%
test = sd_clean.loc[0]['msgs_df'][lambda df: df['title'].str.contains('Department')]
aa = test[lambda df: df['item'].str.contains('Removed')]['item'].str.split('Removed: ').str[-1].str.strip('.').str.split(', ').to_numpy()
aaa = list(set([dept for l in list(aa) for dept in l]))
aaa
# Out:
# []
