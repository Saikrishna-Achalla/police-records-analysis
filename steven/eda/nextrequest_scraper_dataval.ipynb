# %% [markdown]
# # Validating the output data from the NextRequest scraper

# %%
import pandas as pd
import zipfile

# %%
vallejo = pd.read_csv(zipfile.ZipFile('../data/lacity_requests.zip', 'r').open('lacity_requests.csv'))
vallejo
# Out:
#       id  status                                               desc  \
# 0   17-1  CLOSED  From: Andrew Pletcher <Andrew@JMLLAW.com>\nDat...
# 1   17-3  CLOSED  Hello,\n  Relating to Council File No. 12-0621...
# 2   17-4  CLOSED  To Custodian of Records:\n  Pursuant to my rig...
# 3   17-5  CLOSED  Warner Center 2035 Plan section 10.3.1 (a) say...
# 4   17-8  CLOSED  Ordinance/Resolution, staff reports, memorandu...
# 5  17-10  CLOSED  I am writing to you to kindly request a copy o...
# 6  17-11  CLOSED  I am writing to you to kindly request a copy o...
# 7  17-12  CLOSED  This letter serves as a request under the Cali...
# 8  17-14  CLOSED  Dear Melinda:\n This is a request pursuant to ...
# 9  17-15  CLOSED  Per the public records act, please email me th...
#
#                          date       depts  \
# 0  December 4, 2017 via email  City Clerk
# 1    December 8, 2017 via web  City Clerk
# 2    December 8, 2017 via web  City Clerk
# 3    December 8, 2017 via web  City Clerk
# ...
